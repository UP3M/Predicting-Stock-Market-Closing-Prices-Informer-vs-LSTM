# %% [markdown]
# # Informer VS LSTM stock forcating (no extra feature)

# %% [markdown]
# ## Download code and dataset

# %%
# !git clone https://github.com/zhouhaoyi/Informer2020.git
# !git clone https://github.com/UP3M/Predicting-Stock-Market-Closing-Prices-Informer-vs-LSTM
# !ls
# Out:
# Cloning into 'Informer2020'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 576 (delta 199), reused 188 (delta 188), pack-reused 354
# Receiving objects: 100% (576/576), 6.48 MiB | 13.68 MiB/s, done.
# Resolving deltas: 100% (336/336), done.
# Informer2020  sample_data  sentimentAllNews.csv  stock_price.csv

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %%
# !pip install -r ./Informer2020/requirements.txt

# %% [markdown]
# ### Modification on exp_informer.py (to fit with the reseach)

# %%
# Replace the content of exp_informer.py with new setting
new_content = """
from data.data_loader import Dataset_ETT_hour, Dataset_ETT_minute, Dataset_Custom, Dataset_Pred
from exp.exp_basic import Exp_Basic
from models.model import Informer, InformerStack

from utils.tools import EarlyStopping, adjust_learning_rate
from utils.metrics import metric

import numpy as np

import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader

import os
import time

import warnings
warnings.filterwarnings('ignore')

class Exp_Informer(Exp_Basic):
    def __init__(self, args):
        super(Exp_Informer, self).__init__(args)

    def _build_model(self):
        model_dict = {
            'informer':Informer,
            'informerstack':InformerStack,
        }
        if self.args.model=='informer' or self.args.model=='informerstack':
            e_layers = self.args.e_layers if self.args.model=='informer' else self.args.s_layers
            model = model_dict[self.args.model](
                self.args.enc_in,
                self.args.dec_in,
                self.args.c_out,
                self.args.seq_len,
                self.args.label_len,
                self.args.pred_len,
                self.args.factor,
                self.args.d_model,
                self.args.n_heads,
                e_layers, # self.args.e_layers,
                self.args.d_layers,
                self.args.d_ff,
                self.args.dropout,
                self.args.attn,
                self.args.embed,
                self.args.freq,
                self.args.activation,
                self.args.output_attention,
                self.args.distil,
                self.args.mix,
                self.device
            ).float()

        if self.args.use_multi_gpu and self.args.use_gpu:
            model = nn.DataParallel(model, device_ids=self.args.device_ids)
        return model

    def _get_data(self, flag):
        args = self.args

        data_dict = {
            'ETTh1':Dataset_ETT_hour,
            'ETTh2':Dataset_ETT_hour,
            'ETTm1':Dataset_ETT_minute,
            'ETTm2':Dataset_ETT_minute,
            'WTH':Dataset_Custom,
            'ECL':Dataset_Custom,
            'Solar':Dataset_Custom,
            'custom':Dataset_Custom,
        }
        Data = data_dict[self.args.data]
        timeenc = 0 if args.embed!='timeF' else 1

        if flag == 'test':
            shuffle_flag = False; drop_last = True; batch_size = args.batch_size; freq=args.freq
        elif flag=='pred':
            shuffle_flag = False; drop_last = False; batch_size = 1; freq=args.detail_freq
            Data = Dataset_Pred
        else:
            shuffle_flag = True; drop_last = True; batch_size = args.batch_size; freq=args.freq
        data_set = Data(
            root_path=args.root_path,
            data_path=args.data_path,
            flag=flag,
            size=[args.seq_len, args.label_len, args.pred_len],
            features=args.features,
            target=args.target,
            inverse=args.inverse,
            timeenc=timeenc,
            freq=freq,
            cols=args.cols
        )
        print(flag, len(data_set))
        # Save the training data before shuffling
        if flag == 'train':
            data_loader1 = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=shuffle_flag,
            num_workers=args.num_workers,
            drop_last=drop_last)

            data_loader2 = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=False,
            num_workers=args.num_workers,
            drop_last=drop_last)
            return data_set, data_loader1, data_loader2

        data_loader = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=shuffle_flag,
            num_workers=args.num_workers,
            drop_last=drop_last)

        return data_set, data_loader

    def _select_optimizer(self):
        model_optim = optim.Adam(self.model.parameters(), lr=self.args.learning_rate)
        return model_optim

    def _select_criterion(self):
        criterion =  nn.MSELoss()
        return criterion

    def vali(self, vali_data, vali_loader, criterion):
        self.model.eval()
        total_loss = []
        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(vali_loader):
            pred, true = self._process_one_batch(
                vali_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            loss = criterion(pred.detach().cpu(), true.detach().cpu())
            total_loss.append(loss)
        total_loss = np.average(total_loss)
        self.model.train()
        return total_loss

    def train(self, setting, f):
        train_data, train_loader, train_loader2 = self._get_data(flag = 'train')
        vali_data, vali_loader = self._get_data(flag = 'val')
        test_data, test_loader = self._get_data(flag = 'test')

        path = os.path.join(self.args.checkpoints, setting)
        if not os.path.exists(path):
            os.makedirs(path)

        time_now = time.time()

        train_steps = len(train_loader)
        early_stopping = EarlyStopping(patience=self.args.patience, verbose=True)

        model_optim = self._select_optimizer()
        criterion =  self._select_criterion()

        if self.args.use_amp:
            scaler = torch.cuda.amp.GradScaler()

        for epoch in range(self.args.train_epochs):
            iter_count = 0
            train_loss = []
            self.model.train()
            epoch_time = time.time()
            for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(train_loader):
                iter_count += 1

                model_optim.zero_grad()
                pred, true = self._process_one_batch(
                    train_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
                loss = criterion(pred, true)
                train_loss.append(loss.item())

                if (i+1) % 100==0:
                    print("\titers: {0}, epoch: {1} | loss: {2:.7f}".format(i + 1, epoch + 1, loss.item()))
                    speed = (time.time()-time_now)/iter_count
                    left_time = speed*((self.args.train_epochs - epoch)*train_steps - i)
                    print('\tspeed: {:.4f}s/iter; left time: {:.4f}s'.format(speed, left_time))
                    iter_count = 0
                    time_now = time.time()

                if self.args.use_amp:
                    scaler.scale(loss).backward()
                    scaler.step(model_optim)
                    scaler.update()
                else:
                    loss.backward()
                    model_optim.step()

            print("Epoch: {} cost time: {}".format(epoch+1, time.time()-epoch_time))
            train_loss = np.average(train_loss)
            vali_loss = self.vali(vali_data, vali_loader, criterion)
            test_loss = self.vali(test_data, test_loader, criterion)

            print("Epoch: {0}, Steps: {1} | Train Loss: {2:.7f} Vali Loss: {3:.7f} Test Loss: {4:.7f}".format(
                epoch + 1, train_steps, train_loss, vali_loss, test_loss))
            early_stopping(vali_loss, self.model, path)
            if early_stopping.early_stop:
                print("Early stopping")
                break

            adjust_learning_rate(model_optim, epoch+1, self.args)

        # result save
        traindata = []
        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(train_loader2):
            pred, true = self._process_one_batch(
                train_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            traindata.append(true.detach().cpu().numpy())
        traindata = np.array(traindata)
        traindata = traindata.reshape(-1, traindata.shape[-2], traindata.shape[-1])

        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        np.save(folder_path+'traindata.npy', traindata)
        return self.model

    def test(self, setting):
        test_data, test_loader = self._get_data(flag='test')

        self.model.eval()

        preds = []
        trues = []

        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(test_loader):
            pred, true = self._process_one_batch(
                test_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            preds.append(pred.detach().cpu().numpy())
            trues.append(true.detach().cpu().numpy())

        preds = np.array(preds)
        trues = np.array(trues)
        print('test shape:', preds.shape, trues.shape)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
        trues = trues.reshape(-1, trues.shape[-2], trues.shape[-1])
        print('test shape:', preds.shape, trues.shape)

        # result save
        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        mae, mse, rmse, mape, mspe = metric(preds, trues)
        print('mse:{}, mae:{}'.format(mse, mae))

        np.save(folder_path+'metrics.npy', np.array([mae, mse, rmse, mape, mspe]))
        np.save(folder_path+'pred.npy', preds)
        np.save(folder_path+'true.npy', trues)

        return

    def predict(self, setting, load=False):
        pred_data, pred_loader = self._get_data(flag='pred')

        if load:
            path = os.path.join(self.args.checkpoints, setting)
            best_model_path = path+'/'+'checkpoint.pth'
            self.model.load_state_dict(torch.load(best_model_path))

        self.model.eval()

        preds = []

        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
            pred, true = self._process_one_batch(
                pred_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            preds.append(pred.detach().cpu().numpy())

        preds = np.array(preds)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])

        # result save
        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        np.save(folder_path+'real_prediction.npy', preds)

        return

    def _process_one_batch(self, dataset_object, batch_x, batch_y, batch_x_mark, batch_y_mark):
        batch_x = batch_x.float().to(self.device)
        batch_y = batch_y.float()

        batch_x_mark = batch_x_mark.float().to(self.device)
        batch_y_mark = batch_y_mark.float().to(self.device)

        # decoder input
        if self.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], self.args.pred_len, batch_y.shape[-1]]).float()
        elif self.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], self.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:self.args.label_len,:], dec_inp], dim=1).float().to(self.device)
        # encoder - decoder
        if self.args.use_amp:
            with torch.cuda.amp.autocast():
                if self.args.output_attention:
                    outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if self.args.output_attention:
                outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        if self.args.inverse:
            outputs = dataset_object.inverse_transform(outputs)
        f_dim = -1 if self.args.features=='MS' else 0
        batch_y = batch_y[:,-self.args.pred_len:,f_dim:].to(self.device)

        return outputs, batch_y
"""

file_path = '/content/Informer2020/exp/exp_informer.py'
with open(file_path, 'w') as file:
    file.write(new_content)

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd

# Read the CSV files into pandas dataframes
df = pd.read_csv('/content/Predicting-Stock-Market-Closing-Prices-Informer-vs-LSTM/Data/stock_price.csv')

# Convert the date columns to datetime objects with the appropriate format
df['date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d').dt.strftime('%Y-%m-%d %H:%M:%S')

# List of columns to keep
columns_to_keep = ["date", "Close"]

# Filter the DataFrame to keep only the specified columns
df_filtered = df[columns_to_keep]
df_filtered.head(10)
# Out:
#                   date        Close
# 0  2018-12-03 00:00:00  2790.370117
# 1  2018-12-04 00:00:00  2700.060059
# 2  2018-12-06 00:00:00  2695.949951
# 3  2018-12-07 00:00:00  2633.080078
# 4  2018-12-10 00:00:00  2637.719971
# 5  2018-12-11 00:00:00  2636.780029
# 6  2018-12-12 00:00:00  2651.070068
# 7  2018-12-13 00:00:00  2650.540039
# 8  2018-12-14 00:00:00  2599.949951
# 9  2018-12-17 00:00:00  2545.939941

# %% [markdown]
# ## Experiments: Train and Test

# %%
import pandas as pd
import os
from sklearn.model_selection import TimeSeriesSplit

# Set the number of splits (folds)
n_splits = 10

# Initialize TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=n_splits)

# Create a list to store the folds
folds = []
i = 0
for train_index, test_index in tscv.split(df_filtered):
    # Extract DataFrames for the current fold
    train_fold = df_filtered.iloc[train_index].copy()
    test_fold = df_filtered.iloc[test_index].copy()

    # Combine train and test DataFrames into a single DataFrame for the current fold
    combined_fold = pd.concat([train_fold, test_fold])

    #save the data
    if not os.path.exists("/content/fold"):
      os.makedirs("/content/fold")
    combined_fold.to_csv('fold/preprocessed_dataset_{}.csv'.format(i), index=False)

    i += 1

# %%
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch
args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'custom' # data
args.root_path = '/content/' # root path of data file
args.data_path = 'preprocessed_dataset.csv' # data file
args.features = 'S' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'close' # target feature in S or MS task
args.freq = 'd' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 10 # input sequence length of Informer encoder
args.label_len = 5 # start token length of Informer decoder
args.pred_len = 1 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 7 # encoder input size
args.dec_in = 7 # decoder input size
args.c_out = 7 # output size
args.factor = 5 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder
args.mix = True
args.padding = 0
args.freq = 'd'

args.batch_size = 24
args.learning_rate = 0.0001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr = 1
args.train_epochs = 100
args.patience = 3
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
# !rm -r /content/results
# Out:
# rm: cannot remove '/content/results': No such file or directory

# %%
for _ in range (i):
  # Set augments by using data name and adjust the encoder decoder size, based on features
  data_parser = {
      'custom':{'data':'fold/preprocessed_dataset_{}.csv'.format(_),'T':'Close','M':[1,1,1],'S':[1,1,1],'MS':[1,1,1]},
  }
  if args.data in data_parser.keys():
      data_info = data_parser[args.data]
      args.data_path = data_info['data']
      args.target = data_info['T']
      args.enc_in, args.dec_in, args.c_out = data_info[args.features]
      args.detail_freq = args.freq
  args.freq = args.freq[-1:]
  print('Args in experiment:')
  print(args)
  Exp = Exp_Informer
  for ii in range(args.itr):
      # setting record of experiments
      setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}_fold{}'.format(args.model, args.data, args.features,
                  args.seq_len, args.label_len, args.pred_len,
                  args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii, _)

      # set experiments
      exp = Exp(args)

      # train
      print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
      exp.train(setting,_)

      # test
      print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
      exp.test(setting)

      torch.cuda.empty_cache()
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/content/', 'data_path': 'fold/preprocessed_dataset_0.csv', 'features': 'S', 'target': 'Close', 'freq': 'd', 'checkpoints': './informer_checkpoints', 'seq_len': 10, 'label_len': 5, 'pred_len': 1, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftS_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 151
# val 24
# test 46
# Epoch: 1 cost time: 2.6908390522003174
# Epoch: 1, Steps: 6 | Train Loss: 0.8210720 Vali Loss: 0.6534984 Test Loss: 1.2166399
# Validation loss decreased (inf --> 0.653498).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.726597309112549
# Epoch: 2, Steps: 6 | Train Loss: 0.3053639 Vali Loss: 0.2941512 Test Loss: 0.0748608
# Validation loss decreased (0.653498 --> 0.294151).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 2.7627785205841064
# Epoch: 3, Steps: 6 | Train Loss: 0.1432638 Vali Loss: 0.1096205 Test Loss: 0.1702382
# Validation loss decreased (0.294151 --> 0.109620).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 2.3924434185028076
# Epoch: 4, Steps: 6 | Train Loss: 0.1089309 Vali Loss: 0.1228836 Test Loss: 0.1879037
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 2.333378791809082
# Epoch: 5, Steps: 6 | Train Loss: 0.0776467 Vali Loss: 0.0852774 Test Loss: 0.0815527
# Validation loss decreased (0.109620 --> 0.085277).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 2.780111074447632
# Epoch: 6, Steps: 6 | Train Loss: 0.0732989 Vali Loss: 0.0843024 Test Loss: 0.0515182
# Validation loss decreased (0.085277 --> 0.084302).  Saving model ...
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 2.4539215564727783
# Epoch: 7, Steps: 6 | Train Loss: 0.0663993 Vali Loss: 0.0864032 Test Loss: 0.0440113
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 2.324108362197876
# Epoch: 8, Steps: 6 | Train Loss: 0.0659392 Vali Loss: 0.0873226 Test Loss: 0.0416603
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 2.3223917484283447
# Epoch: 9, Steps: 6 | Train Loss: 0.0629758 Vali Loss: 0.0874823 Test Loss: 0.0413650
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftS_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 46
# test shape: (1, 24, 1, 1) (1, 24, 1, 1)
# test shape: (24, 1, 1) (24, 1, 1)
# mse:0.041295409202575684, mae:0.17985160648822784
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/content/', 'data_path': 'fold/preprocessed_dataset_1.csv', 'features': 'S', 'target': 'Close', 'freq': 'd', 'checkpoints': './informer_checkpoints', 'seq_len': 10, 'label_len': 5, 'pred_len': 1, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftS_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 232
# val 35
# test 69
# Epoch: 1 cost time: 4.076679944992065
# Epoch: 1, Steps: 9 | Train Loss: 0.6532252 Vali Loss: 0.2550102 Test Loss: 1.5943310
# Validation loss decreased (inf --> 0.255010).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.3577094078063965
# Epoch: 2, Steps: 9 | Train Loss: 0.2645557 Vali Loss: 1.3308947 Test Loss: 2.5934963
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time:
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 14.195589542388916
# Epoch: 9, Steps: 36 | Train Loss: 0.0166642 Vali Loss: 0.0146097 Test Loss: 0.0080804
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-07
# Epoch: 10 cost time: 14.302668333053589
# Epoch: 10, Steps: 36 | Train Loss: 0.0156800 Vali Loss: 0.0154806 Test Loss: 0.0074921
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftS_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold9<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 253
# test shape: (10, 24, 1, 1) (10, 24, 1, 1)
# test shape: (240, 1, 1) (240, 1, 1)
# mse:0.012533648870885372, mae:0.09129508584737778

# %% [markdown]
# ## LSTM model as comparison

# %%
import os
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from utils.metrics import metric

# Define sequence length
seq_len = 10

def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i])  # Contains feature
        y.append(data[i, 0])  # Close price is the target variable
    return np.array(X), np.array(y)

for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        traindata = np.load(folder_path+'/traindata.npy')
        flipped_array = np.flip(traindata[:,0], axis=1)
        X_train, y_train = create_sequences(flipped_array, seq_len)
        # Building the LSTM Model
        model = Sequential()
        model.add(LSTM(units=70, activation="tanh", return_sequences=True, input_shape=(seq_len, X_train.shape[2])))
        model.add(Dropout(0.2))
        model.add(LSTM(units=30, activation="tanh", return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=10, activation="tanh"))
        model.add(Dropout(0.2))
        model.add(Dense(units=1, activation="linear"))

        model.compile(optimizer='adam', loss='mean_squared_error')

        # Define early stopping
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Train the model with early stopping
        history = model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.1, callbacks=[early_stopping])

        # testing
        testdata = np.load(folder_path+'/true.npy')
        test_flipped_array = np.flip(testdata[:,0], axis=1)
        X_test_new, y_test_new = create_sequences(test_flipped_array, seq_len)

        # Make predictions on the test set and inverse scale for true value comparison
        predictions = model.predict(X_test_new)

        # Calculate evaluation Metrics
        mae, mse, rmse, mape, mspe = metric(y_test_new, predictions)
        print(f'MSE: {mse}')
        print(f'MAE: {mae}')
        print(f'MAPE: {mape * 100:.2f}%')
        np.save(folder_path+'/metrics_lstm.npy', np.array([mae, mse, rmse, mape, mspe]))
        np.save(folder_path+'/pred_lstm.npy', predictions)

    else:
        print(f'Folder {folder_path} does not exist.')
# Out:
# Epoch 1/100
# 6/6 [==============================] - 7s 268ms/step - loss: 0.4877 - val_loss: 1.1700
# Epoch 2/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2495 - val_loss: 0.6986
# Epoch 3/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1279 - val_loss: 0.3855
# Epoch 4/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1207 - val_loss: 0.2370
# Epoch 5/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1051 - val_loss: 0.2185
# Epoch 6/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.1052 - val_loss: 0.2809
# Epoch 7/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.1233 - val_loss: 0.3132
# Epoch 8/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0841 - val_loss: 0.3436
# Epoch 9/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0824 - val_loss: 0.3362
# Epoch 10/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0814 - val_loss: 0.3285
# Epoch 11/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0932 - val_loss: 0.3180
# Epoch 12/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0836 - val_loss: 0.3154
# Epoch 13/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0877 - val_loss: 0.3034
# Epoch 14/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0871 - val_loss: 0.2728
# Epoch 15/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0931 - val_loss: 0.2725
# 1/1 [==============================] - 1s 1s/step
# MSE: 0.18488584458827972
# MAE: 0.4063858389854431
# MAPE: 46.27%
# Epoch 1/100
# 10/10 [==============================] - 7s 153ms/step - loss: 0.4582 - val_loss: 0.2217
# Epoch 2/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1316 - val_loss: 0.0920
# Epoch 3/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1265 - val_loss: 0.0884
# Epoch 4/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1008 - val_loss: 0.0950
# Epoch 5/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0994 - val_loss: 0.0990
# Epoch 6/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1046 - val_loss: 0.0902
# Epoch 7/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0968 - val_loss: 0.0966
# Epoch 8/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1012 - val_loss: 0.0886
# Epoch 9/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1030 - val_loss: 0.0857
# Epoch 10/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0976 - val_loss: 0.0849
# Epoch 11/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0882 - val_loss: 0.0850
# Epoch 12/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0961 - val_loss: 0.0952
# Epoch 13/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0987 - val_loss: 0.0806
# Epoch 14/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0891 - val_loss: 0.0819
# Epoch 15/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0916 - val_loss: 0.0907
# Epoch 16/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0796 - val_loss: 0.0786
# Epoch 17/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0946 - val_loss: 0.0770
# Epoch 18/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0807 - val_loss: 0.0798
# Epoch 19/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0883 - val_loss: 0.0886
# Epoch 20/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0877 - val_loss: 0.0787
# Epoch 21/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0771 - val_loss: 0.0802
# Epoch 22/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0854 - val_loss: 0.0765
# Epoch 23/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0815 - val_loss: 0.0725
# Epoch 24/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0822 - val_loss: 0.0722
# Epoch 25/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0851 - val_loss: 0.0792
# Epoch 26/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0814 - val_loss: 0.0625
# Epoch 27/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0755 - val_loss: 0.0668
# Epoch 28/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0796 - val_loss: 0.0652
# Epoch 29/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0775 - val_loss: 0.0596
# Epoch 30/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0723 - val_loss: 0.0699
# Epoch 31/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0653 - val_loss: 0.0574
# Epoch 32/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0741 - val_loss: 0.0570
# Epoch 33/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0649 - val_loss: 0.0536
# Epoch 34/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0695 - val_loss: 0.0526
# Epoch 35/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0901 - val_loss: 0.0555
# Epoch 36/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0822 - val_loss: 0.0450
# Epoch 37/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0772 - val_loss: 0.0599
# Epoch 38/100
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0778 - val_loss: 0.0566
# Epoch 39/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0765 - val_loss: 0.0482
# Epoch 40/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0699 - val_loss: 0.0514
# Epoch 41/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0688 - val_loss: 0.0475
# Epoch 42/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0747 - val_loss: 0.0513
# Epoch 43/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0658 - val_loss: 0.0455
# Epoch 44/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0708 - val_loss: 0.0435
# Epoch 45/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0696 - val_loss: 0.0509
# Epoch 46/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0701 - val_loss: 0.0450
# Epoch 47/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0658 - val_loss: 0.0474
# Epoch 48/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0647 - val_loss: 0.0496
# Epoch 49/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0681 - val_loss: 0.0392
# Epoch 50/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0701 - val_loss: 0.0468
# Epoch 51/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0684 - val_loss: 0.0453
# Epoch 52/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0636 - val_loss: 0.0472
# Epoch 53/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0678 - val_loss: 0.0639
# Epoch 54/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0611 - val_loss: 0.0417
# Epoch 55/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0600 - val_loss: 0.0458
# Epoch 56/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0682 - val_loss: 0.0427
# Epoch 57/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0561 - val_loss: 0.0467
# Epoch 58/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0592 - val_loss: 0.0381
# Epoch 59/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0747 - val_loss: 0.0518
# Epoch 60/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0564 - val_loss: 0.0377
# Epoch 61/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0599 - val_loss: 0.0438
# Epoch 62/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0651 - val_loss: 0.0463
# Epoch 63/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0626 - val_loss: 0.0384
# Epoch 64/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0685 - val_loss: 0.0545
# Epoch 65/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0623 - val_loss: 0.0418
# Epoch 66/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0719 - val_loss: 0.0400
# Epoch 67/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0686 - val_loss: 0.0489
# Epoch 68/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0625 - val_loss: 0.0379
# Epoch 69/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0607 - val_loss: 0.0382
# Epoch 70/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0614 - val_loss: 0.0515
# 2/2 [==============================] - 1s 10ms/step
# MSE: 5.4417572021484375
# MAE: 1.9285128116607666
# MAPE: 308.93%
# Epoch 1/100
# 14/14 [==============================] - 8s 156ms/step - loss: 0.4804 - val_loss: 1.2645
# Epoch 2/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1156 - val_loss: 1.3544
# Epoch 3/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1036 - val_loss: 1.0627
# Epoch 4/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0927 - val_loss: 1.1044
# Epoch 5/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0695 - val_loss: 1.0556
# Epoch 6/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0614 - val_loss: 1.0732
# Epoch 7/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0657 - val_loss: 1.0435
# Epoch 8/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0586 - val_loss: 1.0671
# Epoch 9/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0610 - val_loss: 1.0490
# Epoch 10/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0666 - val_loss: 1.0433
# Epoch 11/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0588 - val_loss: 0.9696
# Epoch 12/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0636 - val_loss: 1.0866
# Epoch 13/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0568 - val_loss: 1.0220
# Epoch 14/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0595 - val_loss: 1.0349
# Epoch 15/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0641 - val_loss: 0.9774
# Epoch 16/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0544 - val_loss: 1.0293
# Epoch 17/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0582 - val_loss: 0.9582
# Epoch 18/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0575 - val_loss: 1.0364
# Epoch 19/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0683 - val_loss: 0.9377
# Epoch 20/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0609 - val_loss: 1.0186
# Epoch 21/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0516 - val_loss: 0.9881
# Epoch 22/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0563 - val_loss: 0.9538
# Epoch 23/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0562 - val_loss: 0.9560
# Epoch 24/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0524 - val_loss: 0.9126
# Epoch 25/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0477 - val_loss: 0.9380
# Epoch 26/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0534 - val_loss: 0.8569
# Epoch 27/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0485 - val_loss: 0.9513
# Epoch 28/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0495 - val_loss: 0.8192
# Epoch 29/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0490 - val_loss: 0.8809
# Epoch 30/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0638 - val_loss: 0.9233
# Epoch 31/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0509 - val_loss: 0.8334
# Epoch 32/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0480 - val_loss: 0.9235
# Epoch 33/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0472 - val_loss: 0.8266
# Epoch 34/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0486 - val_loss: 0.7886
# Epoch 35/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0483 - val_loss: 0.8170
# Epoch 36/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0418 - val_loss: 0.9088
# Epoch 37/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0589 - val_loss: 0.7690
# Epoch 38/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0485 - val_loss: 0.8165
# Epoch 39/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0469 - val_loss: 0.7917
# Epoch 40/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0553 - val_loss: 0.7952
# Epoch 41/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0448 - val_loss: 0.7994
# Epoch 42/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0542 - val_loss: 0.7434
# Epoch 43/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0457 - val_loss: 0.7828
# Epoch 44/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0428 - val_loss: 0.7757
# Epoch 45/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0473 - val_loss: 0.7362
# Epoch 46/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0461 - val_loss: 0.6557
# Epoch 47/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0477 - val_loss: 0.7024
# Epoch 48/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0444 - val_loss: 0.7290
# Epoch 49/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0462 - val_loss: 0.6697
# Epoch 50/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0369 - val_loss: 0.6953
# Epoch 51/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0444 - val_loss: 0.6793
# Epoch 52/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0475 - val_loss: 0.6422
# Epoch 53/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0422 - val_loss: 0.7200
# Epoch 54/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0470 - val_loss: 0.6873
# Epoch 55/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0437 - val_loss: 0.6305
# Epoch 56/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0462 - val_loss: 0.7249
# Epoch 57/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0456 - val_loss: 0.6587
# Epoch 58/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0459 - val_loss: 0.6908
# Epoch 59/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0365 - val_loss: 0.6767
# Epoch 60/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0425 - val_loss: 0.6404
# Epoch 61/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0392 - val_loss: 0.6502
# Epoch 62/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0467 - val_loss: 0.6263
# Epoch 63/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0404 - val_loss: 0.6988
# Epoch 64/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0355 - val_loss: 0.6707
# Epoch 65/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0410 - val_loss: 0.6111
# Epoch 66/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0403 - val_loss: 0.6717
# Epoch 67/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0423 - val_loss: 0.5990
# Epoch 68/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0366 - val_loss: 0.6598
# Epoch 69/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0435 - val_loss: 0.5724
# Epoch 70/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0384 - val_loss: 0.6469
# Epoch 71/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0351 - val_loss: 0.5856
# Epoch 72/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0401 - val_loss: 0.6521
# Epoch 73/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0427 - val_loss: 0.6242
# Epoch 74/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0371 - val_loss: 0.6361
# Epoch 75/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0451 - val_loss: 0.5753
# Epoch 76/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0404 - val_loss: 0.6455
# Epoch 77/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0408 - val_loss: 0.5575
# Epoch 78/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0388 - val_loss: 0.6660
# Epoch 79/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0451 - val_loss: 0.6103
# Epoch 80/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0377 - val_loss: 0.6032
# Epoch 81/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0434 - val_loss: 0.6180
# Epoch 82/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0396 - val_loss: 0.5675
# Epoch 83/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0431 - val_loss: 0.6035
# Epoch 84/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0392 - val_loss: 0.5865
# Epoch 85/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0371 - val_loss: 0.5996
# Epoch 86/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0355 - val_loss: 0.5789
# Epoch 87/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0350 - val_loss: 0.5573
# Epoch 88/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0483 - val_loss: 0.5547
# Epoch 89/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0466 - val_loss: 0.5447
# Epoch 90/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0414 - val_loss: 0.5752
# Epoch 91/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0365 - val_loss: 0.5410
# Epoch 92/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0335 - val_loss: 0.5570
# Epoch 93/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0460 - val_loss: 0.5587
# Epoch 94/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0372 - val_loss: 0.5265
# Epoch 95/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0355 - val_loss: 0.5699
# Epoch 96/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0376 - val_loss: 0.5665
# Epoch 97/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0352 - val_loss: 0.5278
# Epoch 98/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0409 - val_loss: 0.5612
# Epoch 99/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0401 - val_loss: 0.5257
# Epoch 100/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0320 - val_loss: 0.5405
# 2/2 [==============================] - 1s 12ms/step
# MSE: 0.6505468487739563
# MAE: 0.653010904788971
# MAPE: 58.44%
# Epoch 1/100
# 17/17 [==============================] - 8s 93ms/step - loss: 0.6375 - val_loss: 0.1577
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2521 - val_loss: 0.2166
# Epoch 3/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2496 - val_loss: 0.1598
# Epoch 4/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2224 - val_loss: 0.1599
# Epoch 5/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.2040 - val_loss: 0.1463
# Epoch 6/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1958 - val_loss: 0.1333
# Epoch 7/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1789 - val_loss: 0.1335
# Epoch 8/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1537 - val_loss: 0.1287
# Epoch 9/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1470 - val_loss: 0.1479
# Epoch 10/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1329 - val_loss: 0.1240
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1363 - val_loss: 0.1132
# Epoch 12/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1282 - val_loss: 0.1286
# Epoch 13/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1212 - val_loss: 0.1190
# Epoch 14/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1354 - val_loss: 0.1419
# Epoch 15/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1116 - val_loss: 0.1137
# Epoch 16/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1167 - val_loss: 0.1178
# Epoch 17/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1232 - val_loss: 0.1138
# Epoch 18/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1253 - val_loss: 0.1243
# Epoch 19/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1250 - val_loss: 0.1132
# Epoch 20/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1273 - val_loss: 0.1003
# Epoch 21/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0965 - val_loss: 0.1082
# Epoch 22/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0937 - val_loss: 0.1093
# Epoch 23/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0914 - val_loss: 0.1082
# Epoch 24/100
# 17/17 [==============================] - 0s 28ms/step - loss: 0.0990 - val_loss: 0.1007
# Epoch 25/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1119 - val_loss: 0.1029
# Epoch 26/100
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1056 - val_loss: 0.1005
# Epoch 27/100
# 17/17 [==============================] - 0s 27ms/step - loss: 0.0964 - val_loss: 0.1022
# Epoch 28/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1055 - val_loss: 0.1174
# Epoch 29/100
# 17/17 [==============================] - 0s 26ms/step - loss: 0.1107 - val_loss: 0.1043
# Epoch 30/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0947 - val_loss: 0.1101
# 3/3 [==============================] - 1s 8ms/step
# MSE: 2.867342233657837
# MAE: 1.530852198600769
# MAPE: 79.02%
# Epoch 1/100
# 21/21 [==============================] - 7s 79ms/step - loss: 0.3169 - val_loss: 0.3861
# Epoch 2/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1582 - val_loss: 0.2434
# Epoch 3/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1560 - val_loss: 0.2649
# Epoch 4/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1496 - val_loss: 0.2152
# Epoch 5/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1414 - val_loss: 0.1602
# Epoch 6/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1394 - val_loss: 0.2480
# Epoch 7/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1140 - val_loss: 0.2007
# Epoch 8/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1114 - val_loss: 0.1715
# Epoch 9/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1120 - val_loss: 0.2510
# Epoch 10/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1222 - val_loss: 0.3030
# Epoch 11/100
# 21/21 [==============================] - 1s 25ms/step - loss: 0.1266 - val_loss: 0.1219
# Epoch 12/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0993 - val_loss: 0.1090
# Epoch 13/100
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0843 - val_loss: 0.0877
# Epoch 14/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0895 - val_loss: 0.0577
# Epoch 15/100
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0860 - val_loss: 0.0611
# Epoch 16/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1159 - val_loss: 0.1856
# Epoch 17/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0988 - val_loss: 0.2046
# Epoch 18/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0926 - val_loss: 0.0943
# Epoch 19/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0912 - val_loss: 0.1247
# Epoch 20/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0856 - val_loss: 0.1179
# Epoch 21/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0694 - val_loss: 0.1178
# Epoch 22/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0820 - val_loss: 0.0953
# Epoch 23/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0804 - val_loss: 0.1391
# Epoch 24/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0740 - val_loss: 0.0991
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7d9afd5c5630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 1s 6ms/step
# MSE: 6.366886615753174
# MAE: 2.445829153060913
# MAPE: 117.08%
# Epoch 1/100
# 25/25 [==============================] - 8s 92ms/step - loss: 0.2957 - val_loss: 1.0703
# Epoch 2/100
# 25/25 [==============================] - 1s 27ms/step - loss: 0.1046 - val_loss: 0.7258
# Epoch 3/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0913 - val_loss: 0.4835
# Epoch 4/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0957 - val_loss: 0.3623
# Epoch 5/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0855 - val_loss: 0.3573
# Epoch 6/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0737 - val_loss: 0.2772
# Epoch 7/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0738 - val_loss: 0.2592
# Epoch 8/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0644 - val_loss: 0.1002
# Epoch 9/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0668 - val_loss: 0.1027
# Epoch 10/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0607 - val_loss: 0.2232
# Epoch 11/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0631 - val_loss: 0.1498
# Epoch 12/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0585 - val_loss: 0.2323
# Epoch 13/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0577 - val_loss: 0.1080
# Epoch 14/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0593 - val_loss: 0.1692
# Epoch 15/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0627 - val_loss: 0.2190
# Epoch 16/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0623 - val_loss: 0.1266
# Epoch 17/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0570 - val_loss: 0.1395
# Epoch 18/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0564 - val_loss: 0.0618
# Epoch 19/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0600 - val_loss: 0.1327
# Epoch 20/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0514 - val_loss: 0.1035
# Epoch 21/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0468 - val_loss: 0.0798
# Epoch 22/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0579 - val_loss: 0.0991
# Epoch 23/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0540 - val_loss: 0.1698
# Epoch 24/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0583 - val_loss: 0.1934
# Epoch 25/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0514 - val_loss: 0.0948
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0447 - val_loss: 0.1536
# Epoch 27/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0491 - val_loss: 0.0842
# Epoch 28/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0393 - val_loss: 0.0525
# Epoch 29/100
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0445 - val_loss: 0.0490
# Epoch 30/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0447 - val_loss: 0.0521
# Epoch 31/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0397 - val_loss: 0.0718
# Epoch 32/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0420 - val_loss: 0.0646
# Epoch 33/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0454 - val_loss: 0.1010
# Epoch 34/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0438 - val_loss: 0.2170
# Epoch 35/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0453 - val_loss: 0.1748
# Epoch 36/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0469 - val_loss: 0.0460
# Epoch 37/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0455 - val_loss: 0.1217
# Epoch 38/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0465 - val_loss: 0.0781
# Epoch 39/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0413 - val_loss: 0.1211
# Epoch 40/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0430 - val_loss: 0.0412
# Epoch 41/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0340 - val_loss: 0.0210
# Epoch 42/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0384 - val_loss: 0.0703
# Epoch 43/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0469 - val_loss: 0.0298
# Epoch 44/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0367 - val_loss: 0.0835
# Epoch 45/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0376 - val_loss: 0.1479
# Epoch 46/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0361 - val_loss: 0.0862
# Epoch 47/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0397 - val_loss: 0.0635
# Epoch 48/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0367 - val_loss: 0.0683
# Epoch 49/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0415 - val_loss: 0.1696
# Epoch 50/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0388 - val_loss: 0.0519
# Epoch 51/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0355 - val_loss: 0.0526
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7d9b0ef86b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 [==============================] - 1s 6ms/step
# MSE: 2.633774995803833
# MAE: 1.5775489807128906
# MAPE: 64.52%
# Epoch 1/100
# 28/28 [==============================] - 8s 89ms/step - loss: 0.2472 - val_loss: 0.4454
# Epoch 2/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0766 - val_loss: 0.4882
# Epoch 3/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0686 - val_loss: 0.3116
# Epoch 4/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0611 - val_loss: 0.2197
# Epoch 5/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0572 - val_loss: 0.1040
# Epoch 6/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0540 - val_loss: 0.1427
# Epoch 7/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0570 - val_loss: 0.1678
# Epoch 8/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0495 - val_loss: 0.1198
# Epoch 9/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0516 - val_loss: 0.0484
# Epoch 10/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0488 - val_loss: 0.0502
# Epoch 11/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0425 - val_loss: 0.1279
# Epoch 12/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0513 - val_loss: 0.0817
# Epoch 13/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0409 - val_loss: 0.0644
# Epoch 14/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0449 - val_loss: 0.1993
# Epoch 15/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0452 - val_loss: 0.1251
# Epoch 16/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0463 - val_loss: 0.1298
# Epoch 17/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0438 - val_loss: 0.0697
# Epoch 18/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0382 - val_loss: 0.0796
# Epoch 19/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0397 - val_loss: 0.0836
# 5/5 [==============================] - 1s 6ms/step
# MSE: 0.700891375541687
# MAE: 0.7222667932510376
# MAPE: 40.33%
# Epoch 1/100
# 31/31 [==============================] - 9s 58ms/step - loss: 0.2385 - val_loss: 0.2814
# Epoch 2/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0677 - val_loss: 0.2985
# Epoch 3/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0512 - val_loss: 0.1423
# Epoch 4/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0522 - val_loss: 0.0891
# Epoch 5/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0522 - val_loss: 0.0325
# Epoch 6/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0485 - val_loss: 0.0639
# Epoch 7/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0433 - val_loss: 0.0201
# Epoch 8/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0438 - val_loss: 0.0294
# Epoch 9/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0397 - val_loss: 0.0329
# Epoch 10/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0402 - val_loss: 0.0173
# Epoch 11/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0427 - val_loss: 0.0920
# Epoch 12/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0429 - val_loss: 0.0553
# Epoch 13/100
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0403 - val_loss: 0.0342
# Epoch 14/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0378 - val_loss: 0.0613
# Epoch 15/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0353 - val_loss: 0.0350
# Epoch 16/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0327 - val_loss: 0.0201
# Epoch 17/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0354 - val_loss: 0.0782
# Epoch 18/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0372 - val_loss: 0.0175
# Epoch 19/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0323 - val_loss: 0.0117
# Epoch 20/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0332 - val_loss: 0.0201
# Epoch 21/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0330 - val_loss: 0.0142
# Epoch 22/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0333 - val_loss: 0.0145
# Epoch 23/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0347 - val_loss: 0.0078
# Epoch 24/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0330 - val_loss: 0.0067
# Epoch 25/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0304 - val_loss: 0.0105
# Epoch 26/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0308 - val_loss: 0.0210
# Epoch 27/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0343 - val_loss: 0.0331
# Epoch 28/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0315 - val_loss: 0.0247
# Epoch 29/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0275 - val_loss: 0.0189
# Epoch 30/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0290 - val_loss: 0.0590
# Epoch 31/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0294 - val_loss: 0.0706
# Epoch 32/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0280 - val_loss: 0.0572
# Epoch 33/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0296 - val_loss: 0.0307
# Epoch 34/100
# 31/31 [==============================] - 1s 22ms/step - loss: 0.0261 - val_loss: 0.0334
# 6/6 [==============================] - 1s 6ms/step
# MSE: 0.27079105377197266
# MAE: 0.41658419370651245
# MAPE: 37.18%
# Epoch 1/100
# 36/36 [==============================] - 8s 51ms/step - loss: 0.2016 - val_loss: 0.1313
# Epoch 2/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0562 - val_loss: 0.1275
# Epoch 3/100
# 36/36 [==============================] - 1s 15ms/step - loss: 0.0505 - val_loss: 0.1469
# Epoch 4/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0442 - val_loss: 0.0611
# Epoch 5/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0427 - val_loss: 0.1070
# Epoch 6/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0366 - val_loss: 0.1169
# Epoch 7/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0367 - val_loss: 0.0590
# Epoch 8/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0389 - val_loss: 0.0617
# Epoch 9/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0345 - val_loss: 0.0587
# Epoch 10/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.0341 - val_loss: 0.0723
# Epoch 11/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.0357 - val_loss: 0.0472
# Epoch 12/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0356 - val_loss: 0.0498
# Epoch 13/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0349 - val_loss: 0.0269
# Epoch 14/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0343 - val_loss: 0.0870
# Epoch 15/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0372 - val_loss: 0.0589
# Epoch 16/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0350 - val_loss: 0.0611
# Epoch 17/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0347 - val_loss: 0.0728
# Epoch 18/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0341 - val_loss: 0.0473
# Epoch 19/100
# 36/36 [==============================] - 1s 15ms/step - loss: 0.0341 - val_loss: 0.0433
# Epoch 20/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0314 - val_loss: 0.0558
# Epoch 21/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0330 - val_loss: 0.0194
# Epoch 22/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0329 - val_loss: 0.0596
# Epoch 23/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0299 - val_loss: 0.0396
# Epoch 24/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0325 - val_loss: 0.0310
# Epoch 25/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0341 - val_loss: 0.0308
# Epoch 26/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0362 - val_loss: 0.0770
# Epoch 27/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0352 - val_loss: 0.0245
# Epoch 28/100
# 36/36 [==============================] - 1s 19ms/step - loss: 0.0350 - val_loss: 0.1002
# Epoch 29/100
# 36/36 [==============================] - 1s 23ms/step - loss: 0.0311 - val_loss: 0.0272
# Epoch 30/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.0302 - val_loss: 0.0520
# Epoch 31/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0290 - val_loss: 0.0560
# 7/7 [==============================] - 1s 5ms/step
# MSE: 0.14961914718151093
# MAE: 0.31279948353767395
# MAPE: 36.39%
# Epoch 1/100
# 39/39 [==============================] - 8s 48ms/step - loss: 0.2461 - val_loss: 0.0738
# Epoch 2/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0584 - val_loss: 0.0401
# Epoch 3/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0600 - val_loss: 0.0579
# Epoch 4/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0487 - val_loss: 0.0370
# Epoch 5/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0458 - val_loss: 0.0347
# Epoch 6/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0458 - val_loss: 0.0341
# Epoch 7/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0430 - val_loss: 0.0608
# Epoch 8/100
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0425 - val_loss: 0.0339
# Epoch 9/100
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0421 - val_loss: 0.0354
# Epoch 10/100
# 39/39 [==============================] - 1s 23ms/step - loss: 0.0445 - val_loss: 0.0402
# Epoch 11/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0386 - val_loss: 0.0345
# Epoch 12/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0417 - val_loss: 0.0588
# Epoch 13/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0439 - val_loss: 0.0326
# Epoch 14/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0409 - val_loss: 0.0488
# Epoch 15/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0390 - val_loss: 0.0726
# Epoch 16/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0460 - val_loss: 0.0684
# Epoch 17/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0372 - val_loss: 0.0325
# Epoch 18/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0376 - val_loss: 0.0533
# Epoch 19/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0373 - val_loss: 0.0433
# Epoch 20/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0385 - val_loss: 0.0321
# Epoch 21/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0357 - val_loss: 0.0391
# Epoch 22/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0427 - val_loss: 0.0319
# Epoch 23/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0372 - val_loss: 0.0460
# Epoch 24/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0370 - val_loss: 0.0518
# Epoch 25/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0393 - val_loss: 0.0317
# Epoch 26/100
# 39/39 [==============================] - 1s 21ms/step - loss: 0.0353 - val_loss: 0.0544
# Epoch 27/100
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0368 - val_loss: 0.0364
# Epoch 28/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0345 - val_loss: 0.0365
# Epoch 29/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0381 - val_loss: 0.0320
# Epoch 30/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0310 - val_loss: 0.0310
# Epoch 31/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0333 - val_loss: 0.0373
# Epoch 32/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0372 - val_loss: 0.0465
# Epoch 33/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0371 - val_loss: 0.0385
# Epoch 34/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0343 - val_loss: 0.0374
# Epoch 35/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0342 - val_loss: 0.0292
# Epoch 36/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0358 - val_loss: 0.0290
# Epoch 37/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0344 - val_loss: 0.0375
# Epoch 38/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0349 - val_loss: 0.0420
# Epoch 39/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0341 - val_loss: 0.0284
# Epoch 40/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0371 - val_loss: 0.0392
# Epoch 41/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0329 - val_loss: 0.0378
# Epoch 42/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0297 - val_loss: 0.0349
# Epoch 43/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0338 - val_loss: 0.0292
# Epoch 44/100
# 39/39 [==============================] - 1s 21ms/step - loss: 0.0347 - val_loss: 0.0323
# Epoch 45/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0340 - val_loss: 0.0571
# Epoch 46/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0328 - val_loss: 0.0302
# Epoch 47/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0364 - val_loss: 0.0269
# Epoch 48/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0332 - val_loss: 0.0334
# Epoch 49/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0333 - val_loss: 0.0282
# Epoch 50/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0350 - val_loss: 0.0360
# Epoch 51/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0327 - val_loss: 0.0276
# Epoch 52/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0343 - val_loss: 0.0601
# Epoch 53/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0328 - val_loss: 0.0353
# Epoch 54/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0322 - val_loss: 0.0333
# Epoch 55/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0329 - val_loss: 0.0282
# Epoch 56/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0342 - val_loss: 0.0268
# Epoch 57/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0326 - val_loss: 0.0331
# Epoch 58/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0332 - val_loss: 0.0329
# Epoch 59/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0314 - val_loss: 0.0430
# Epoch 60/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0327 - val_loss: 0.0264
# Epoch 61/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0328 - val_loss: 0.0260
# Epoch 62/100
# 39/39 [==============================] - 1s 22ms/step - loss: 0.0315 - val_loss: 0.0346
# Epoch 63/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0313 - val_loss: 0.0307
# Epoch 64/100
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0331 - val_loss: 0.0266
# Epoch 65/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0344 - val_loss: 0.0303
# Epoch 66/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0296 - val_loss: 0.0264
# Epoch 67/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0315 - val_loss: 0.0455
# Epoch 68/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0342 - val_loss: 0.0308
# Epoch 69/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0382 - val_loss: 0.0246
# Epoch 70/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0358 - val_loss: 0.0293
# Epoch 71/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0320 - val_loss: 0.0276
# Epoch 72/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0307 - val_loss: 0.0262
# Epoch 73/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0297 - val_loss: 0.0259
# Epoch 74/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0325 - val_loss: 0.0260
# Epoch 75/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0311 - val_loss: 0.0293
# Epoch 76/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0330 - val_loss: 0.0267
# Epoch 77/100
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0309 - val_loss: 0.0273
# Epoch 78/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0355 - val_loss: 0.0403
# Epoch 79/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0312 - val_loss: 0.0286
# 8/8 [==============================] - 1s 5ms/step
# MSE: 0.1748138964176178
# MAE: 0.3405211865901947
# MAPE: 40.60%

# %% [markdown]
# ## Result and Visualization

# %%
for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        g_truth = np.load(folder_path+'/true.npy')
        pred_informer = np.load(folder_path+'/pred.npy')
        pred_lstm = np.load(folder_path+'/pred_lstm.npy')
        x_values = np.arange(len(pred_lstm)) + 10

        plt.figure(figsize=(15, 6))
        plt.plot(g_truth[:,:,0], label='Actual Closing Prices')
        plt.plot(pred_informer[:,:,0], label='Informer')
        plt.plot(x_values, pred_lstm[:, 0], label='LSTM (Shifted 10 steps forward)')
        plt.title('Stock Price Prediction')
        plt.xlabel('Index')
        plt.ylabel('Stock Price')
        plt.legend()
        plt.show()

# %%
mae = []
mse = []
rmse = []
mape = []
mspe = []

mael = []
msel = []
rmsel = []
mapel = []
mspel = []

for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        inf_m = np.load(folder_path+'/metrics.npy')
        l_m = np.load(folder_path+'/metrics_lstm.npy')
        mse.append(inf_m[1])
        rmse.append(inf_m[2])
        mape.append(inf_m[3])
        mspel.append(inf_m[4])
        mae.append(inf_m[0])

        msel.append(l_m[1])
        rmsel.append(l_m[2])
        mapel.append(l_m[3])
        mspel.append(l_m[4])
        mael.append(l_m[0])

# Calculate the standard deviation of MSE across folds
std_mse_inf = np.std(mse)
mean_mse_inf = np.mean(mse)
print("mean MSE Informer:", mean_mse_inf)
print("std MSE Informer: ", std_mse_inf)

# Calculate the standard deviation of MSE across folds
std_mse_lstm = np.std(msel)
mean_mse_lstm = np.mean(msel)
print("mean MSE LSTM:", mean_mse_lstm)
print("std MSE LSTM: ", std_mse_lstm)
# Out:
# mean MSE Informer: 1.2439345
# std MSE Informer:  1.8025911
# mean MSE LSTM: 1.9441311
# std MSE LSTM:  2.2042427

# %%
# Calculate the standard deviation of MAE across folds
std_mae_inf = np.std(mae)
mean_mae_inf = np.mean(mae)
print("mean MAE Informer:", mean_mae_inf)
print("std MAE Informer: ", std_mae_inf)

# Calculate the standard deviation of MAE across folds
std_mae_lstm = np.std(mael)
mean_mae_lstm = np.mean(mael)
print("mean MAE LSTM:", mean_mae_lstm)
print("std MAE LSTM: ", std_mae_lstm)
# Out:
# mean MAE Informer: 0.74597317
# std MAE Informer:  0.7404587
# mean MAE LSTM: 1.0334312
# std MAE LSTM:  0.7317236

# %%
# Calculate the standard deviation of MAPE across folds
std_mape_inf = np.std(mape)
mean_mape_inf = np.mean(mape)
print("mean MAPE Informer:", mean_mape_inf)
print("std MAPE Informer: ", std_mape_inf)

# Calculate the standard deviation of MAPE across folds
std_mape_lstm = np.std(mapel)
mean_mape_lstm = np.mean(mapel)
print("mean MAPE LSTM:", mean_mape_lstm)
print("std MAPE LSTM: ", std_mape_lstm)
# Out:
# mean MAPE Informer: 0.28082818
# std MAPE Informer:  0.1517624
# mean MAPE LSTM: 0.82875365
# std MAPE LSTM:  0.78997475

# %%
# Calculate the standard deviation of RMSE across folds
std_rmse_inf = np.std(rmse)
mean_rmse_inf = np.mean(rmse)
print("mean RMSE Informer:", mean_rmse_inf)
print("std RMSE Informer: ", std_rmse_inf)

# Calculate the standard deviation of RMSE across folds
std_rmse_lstm = np.std(rmsel)
mean_rmse_lstm = np.mean(rmsel)
print("mean RMSE LSTM:", mean_rmse_lstm)
print("std RMSE LSTM: ", std_rmse_lstm)
# Out:
# mean RMSE Informer: 0.81455886
# std RMSE Informer:  0.7618584
# mean RMSE LSTM: 1.1571271
# std RMSE LSTM:  0.7779382

# %% [markdown]
# ## Rescale the Result

# %%
from sklearn.preprocessing import StandardScaler

for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        g_truth = np.load(folder_path+'/true.npy')
        pred_informer = np.load(folder_path+'/pred.npy')
        pred_lstm = np.load(folder_path+'/pred_lstm.npy')

        # Load the CSV file into a DataFrame
        data_ori = pd.read_csv("/content/fold/preprocessed_dataset_{}".format(i)+".csv")

        # Extract a specific column into an array
        close_price = data_ori["Close"].values

        # Reshape the array if it's 1D (required by StandardScaler)
        close_price = close_price.reshape(-1, 1)

        # Initialize a StandardScaler object and fit it to the column data
        scaler = StandardScaler()
        scaler.fit(close_price)
        g_truth = scaler.inverse_transform(g_truth[:,:,0])
        pred_informer = scaler.inverse_transform(pred_informer[:,:,0])
        pred_lstm = scaler.inverse_transform(pred_lstm)

        maeL, mseL, rmseL, mapeL, mspeL = metric(pred_lstm, g_truth[10:])
        mae, mse, rmse, mape, mspe = metric(pred_informer, g_truth)
        x_values = np.arange(len(pred_lstm)) + 10

        print("LSTM-> MAE:", maeL, "MSE: ", mseL, "RMSE: ", rmseL, "MAPE: ", mapeL,"MSPE: ", mspeL)
        print("Informer-> MAE:", mae, "MSE: ", mse, "RMSE: ", rmse, "MAPE: ", mape,"MSPE: ", mspe)
        np.save(folder_path+'/inv_metrics_inf.npy', np.array([mae, mse, rmse, mape, mspe]))
        np.save(folder_path+'/inv_metrics_lstm.npy', np.array([maeL, mseL, rmseL, mapeL, mspeL]))


        plt.figure(figsize=(15, 6))
        plt.plot(g_truth[:,:], label='Actual Closing Prices')
        plt.plot(pred_informer[:,:], label='Informer')
        plt.plot(x_values, pred_lstm[:, 0], label='LSTM')
        plt.title('Stock Price Prediction')
        plt.xlabel('Index')
        plt.ylabel('Stock Price')
        plt.legend()
        plt.show()
