# %% [markdown]
# # Informer VS LSTM stock forcating (sentiment + technical analysis)

# %% [markdown]
# ## Download code and dataset

# %%
# !git clone https://github.com/zhouhaoyi/Informer2020.git
# !ls
# Out:
# Cloning into 'Informer2020'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 576 (delta 199), reused 188 (delta 188), pack-reused 354
# Receiving objects: 100% (576/576), 6.48 MiB | 19.28 MiB/s, done.
# Resolving deltas: 100% (336/336), done.
# Informer2020  sample_data  sentimentAllNews.csv  stock_price.csv

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %%
# !pip install -r ./Informer2020/requirements.txt

# %% [markdown]
# ### edited exp_informer.py

# %%
# Replace the content of exp_informer.py with new setting
new_content = """
from data.data_loader import Dataset_ETT_hour, Dataset_ETT_minute, Dataset_Custom, Dataset_Pred
from exp.exp_basic import Exp_Basic
from models.model import Informer, InformerStack

from utils.tools import EarlyStopping, adjust_learning_rate
from utils.metrics import metric

import numpy as np

import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader

import os
import time

import warnings
warnings.filterwarnings('ignore')

class Exp_Informer(Exp_Basic):
    def __init__(self, args):
        super(Exp_Informer, self).__init__(args)

    def _build_model(self):
        model_dict = {
            'informer':Informer,
            'informerstack':InformerStack,
        }
        if self.args.model=='informer' or self.args.model=='informerstack':
            e_layers = self.args.e_layers if self.args.model=='informer' else self.args.s_layers
            model = model_dict[self.args.model](
                self.args.enc_in,
                self.args.dec_in,
                self.args.c_out,
                self.args.seq_len,
                self.args.label_len,
                self.args.pred_len,
                self.args.factor,
                self.args.d_model,
                self.args.n_heads,
                e_layers, # self.args.e_layers,
                self.args.d_layers,
                self.args.d_ff,
                self.args.dropout,
                self.args.attn,
                self.args.embed,
                self.args.freq,
                self.args.activation,
                self.args.output_attention,
                self.args.distil,
                self.args.mix,
                self.device
            ).float()

        if self.args.use_multi_gpu and self.args.use_gpu:
            model = nn.DataParallel(model, device_ids=self.args.device_ids)
        return model

    def _get_data(self, flag):
        args = self.args

        data_dict = {
            'ETTh1':Dataset_ETT_hour,
            'ETTh2':Dataset_ETT_hour,
            'ETTm1':Dataset_ETT_minute,
            'ETTm2':Dataset_ETT_minute,
            'WTH':Dataset_Custom,
            'ECL':Dataset_Custom,
            'Solar':Dataset_Custom,
            'custom':Dataset_Custom,
        }
        Data = data_dict[self.args.data]
        timeenc = 0 if args.embed!='timeF' else 1

        if flag == 'test':
            shuffle_flag = False; drop_last = True; batch_size = args.batch_size; freq=args.freq
        elif flag=='pred':
            shuffle_flag = False; drop_last = False; batch_size = 1; freq=args.detail_freq
            Data = Dataset_Pred
        else:
            shuffle_flag = True; drop_last = True; batch_size = args.batch_size; freq=args.freq
        data_set = Data(
            root_path=args.root_path,
            data_path=args.data_path,
            flag=flag,
            size=[args.seq_len, args.label_len, args.pred_len],
            features=args.features,
            target=args.target,
            inverse=args.inverse,
            timeenc=timeenc,
            freq=freq,
            cols=args.cols
        )
        print(flag, len(data_set))
        # Save the training data before shuffling
        if flag == 'train':
            data_loader1 = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=shuffle_flag,
            num_workers=args.num_workers,
            drop_last=drop_last)

            data_loader2 = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=False,
            num_workers=args.num_workers,
            drop_last=drop_last)
            return data_set, data_loader1, data_loader2

        data_loader = DataLoader(
            data_set,
            batch_size=batch_size,
            shuffle=shuffle_flag,
            num_workers=args.num_workers,
            drop_last=drop_last)

        return data_set, data_loader

    def _select_optimizer(self):
        model_optim = optim.Adam(self.model.parameters(), lr=self.args.learning_rate)
        return model_optim

    def _select_criterion(self):
        criterion =  nn.MSELoss()
        return criterion

    def vali(self, vali_data, vali_loader, criterion):
        self.model.eval()
        total_loss = []
        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(vali_loader):
            pred, true = self._process_one_batch(
                vali_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            loss = criterion(pred.detach().cpu(), true.detach().cpu())
            total_loss.append(loss)
        total_loss = np.average(total_loss)
        self.model.train()
        return total_loss

    def train(self, setting, f):
        train_data, train_loader, train_loader2 = self._get_data(flag = 'train')
        vali_data, vali_loader = self._get_data(flag = 'val')
        test_data, test_loader = self._get_data(flag = 'test')

        path = os.path.join(self.args.checkpoints, setting)
        if not os.path.exists(path):
            os.makedirs(path)

        time_now = time.time()

        train_steps = len(train_loader)
        early_stopping = EarlyStopping(patience=self.args.patience, verbose=True)

        model_optim = self._select_optimizer()
        criterion =  self._select_criterion()

        if self.args.use_amp:
            scaler = torch.cuda.amp.GradScaler()

        for epoch in range(self.args.train_epochs):
            iter_count = 0
            train_loss = []
            self.model.train()
            epoch_time = time.time()
            for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(train_loader):
                iter_count += 1

                model_optim.zero_grad()
                pred, true = self._process_one_batch(
                    train_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
                loss = criterion(pred, true)
                train_loss.append(loss.item())

                if (i+1) % 100==0:
                    print("\titers: {0}, epoch: {1} | loss: {2:.7f}".format(i + 1, epoch + 1, loss.item()))
                    speed = (time.time()-time_now)/iter_count
                    left_time = speed*((self.args.train_epochs - epoch)*train_steps - i)
                    print('\tspeed: {:.4f}s/iter; left time: {:.4f}s'.format(speed, left_time))
                    iter_count = 0
                    time_now = time.time()

                if self.args.use_amp:
                    scaler.scale(loss).backward()
                    scaler.step(model_optim)
                    scaler.update()
                else:
                    loss.backward()
                    model_optim.step()

            print("Epoch: {} cost time: {}".format(epoch+1, time.time()-epoch_time))
            train_loss = np.average(train_loss)
            vali_loss = self.vali(vali_data, vali_loader, criterion)
            test_loss = self.vali(test_data, test_loader, criterion)

            print("Epoch: {0}, Steps: {1} | Train Loss: {2:.7f} Vali Loss: {3:.7f} Test Loss: {4:.7f}".format(
                epoch + 1, train_steps, train_loss, vali_loss, test_loss))
            early_stopping(vali_loss, self.model, path)
            if early_stopping.early_stop:
                print("Early stopping")
                break

            adjust_learning_rate(model_optim, epoch+1, self.args)

        # result save
        traindata = []
        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(train_loader2):
            pred, true = self._process_one_batch(
                train_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            traindata.append(true.detach().cpu().numpy())
        traindata = np.array(traindata)
        traindata = traindata.reshape(-1, traindata.shape[-2], traindata.shape[-1])

        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        np.save(folder_path+'traindata.npy', traindata)
        return self.model

    def test(self, setting):
        test_data, test_loader = self._get_data(flag='test')

        self.model.eval()

        preds = []
        trues = []

        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(test_loader):
            pred, true = self._process_one_batch(
                test_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            preds.append(pred.detach().cpu().numpy())
            trues.append(true.detach().cpu().numpy())

        preds = np.array(preds)
        trues = np.array(trues)
        print('test shape:', preds.shape, trues.shape)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
        trues = trues.reshape(-1, trues.shape[-2], trues.shape[-1])
        print('test shape:', preds.shape, trues.shape)

        # result save
        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        mae, mse, rmse, mape, mspe = metric(preds, trues)
        print('mse:{}, mae:{}'.format(mse, mae))

        np.save(folder_path+'metrics.npy', np.array([mae, mse, rmse, mape, mspe]))
        np.save(folder_path+'pred.npy', preds)
        np.save(folder_path+'true.npy', trues)

        return

    def predict(self, setting, load=False):
        pred_data, pred_loader = self._get_data(flag='pred')

        if load:
            path = os.path.join(self.args.checkpoints, setting)
            best_model_path = path+'/'+'checkpoint.pth'
            self.model.load_state_dict(torch.load(best_model_path))

        self.model.eval()

        preds = []

        for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
            pred, true = self._process_one_batch(
                pred_data, batch_x, batch_y, batch_x_mark, batch_y_mark)
            preds.append(pred.detach().cpu().numpy())

        preds = np.array(preds)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])

        # result save
        folder_path = './results/' + setting +'/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        np.save(folder_path+'real_prediction.npy', preds)

        return

    def _process_one_batch(self, dataset_object, batch_x, batch_y, batch_x_mark, batch_y_mark):
        batch_x = batch_x.float().to(self.device)
        batch_y = batch_y.float()

        batch_x_mark = batch_x_mark.float().to(self.device)
        batch_y_mark = batch_y_mark.float().to(self.device)

        # decoder input
        if self.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], self.args.pred_len, batch_y.shape[-1]]).float()
        elif self.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], self.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:self.args.label_len,:], dec_inp], dim=1).float().to(self.device)
        # encoder - decoder
        if self.args.use_amp:
            with torch.cuda.amp.autocast():
                if self.args.output_attention:
                    outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if self.args.output_attention:
                outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        if self.args.inverse:
            outputs = dataset_object.inverse_transform(outputs)
        f_dim = -1 if self.args.features=='MS' else 0
        batch_y = batch_y[:,-self.args.pred_len:,f_dim:].to(self.device)

        return outputs, batch_y
"""

# Use the %writefile magic command to overwrite the content of file.py
file_path = '/content/Informer2020/exp/exp_informer.py'  # Change the path accordingly
with open(file_path, 'w') as file:
    file.write(new_content)

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd

# Read the CSV files into pandas dataframes
df1 = pd.read_csv('sentimentAllNews.csv')
df2 = pd.read_csv('stock_price.csv')

# df2['Date'] = df2['Date'].str[:-6]
df2['Date'] = pd.to_datetime(df2['Date'], format='%Y-%m-%d %H:%M:%S')

# Convert the date columns to datetime objects with the appropriate format
df1['Date'] = pd.to_datetime(df1['Date'], format='%Y-%m-%d')

# Merge the dataframes on the 'date' column
merged_df = pd.merge(df2, df1, on='Date', how='inner')
# Format the 'Date' column to include %H:%M:%S
merged_df['date'] = merged_df['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')

# List of columns to keep
# columns_to_keep = ["date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "FinBERT score"]
columns_to_keep = ["date", "Close", "FinBERT score"]

# Filter the DataFrame to keep only the specified columns
df_filtered = merged_df[columns_to_keep]
df_filtered.head(10)
# Out:
#                   date        Close  FinBERT score
# 0  2018-12-03 00:00:00  2790.370117       0.774478
# 1  2018-12-04 00:00:00  2700.060059      -0.867316
# 2  2018-12-06 00:00:00  2695.949951      -0.932069
# 3  2018-12-07 00:00:00  2633.080078      -0.569444
# 4  2018-12-10 00:00:00  2637.719971       0.000000
# 5  2018-12-11 00:00:00  2636.780029      -0.551899
# 6  2018-12-12 00:00:00  2651.070068       0.000000
# 7  2018-12-13 00:00:00  2650.540039       0.000000
# 8  2018-12-14 00:00:00  2599.949951      -0.907713
# 9  2018-12-17 00:00:00  2545.939941      -0.950848

# %% [markdown]
# ## Apply Technical Analysis (TA)

# %%
# !pip install stockstats
# Out:
# Collecting stockstats
#   Downloading stockstats-0.6.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from stockstats) (1.25.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from stockstats) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->stockstats) (1.16.0)
# Installing collected packages: stockstats
# Successfully installed stockstats-0.6.2

# %%
from stockstats import wrap, unwrap
df = wrap(df_filtered)
df_filtered['rsi'] = df['rsi']
df_filtered['macd'] = df['macd']
df_filtered = unwrap(df_filtered)
df_filtered = df_filtered.fillna(0)
df_filtered.head(10)
# Out:
# <ipython-input-7-38311e2b5dec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['rsi'] = df['rsi']
# <ipython-input-7-38311e2b5dec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['macd'] = df['macd']
#                            close  finbert score        rsi       macd  \
# date
# 2018-12-03 00:00:00  2790.370117       0.774478   0.000000   0.000000
# 2018-12-04 00:00:00  2700.060059      -0.867316   0.000000  -2.026187
# 2018-12-06 00:00:00  2695.949951      -0.932069   0.000000  -2.709219
# 2018-12-07 00:00:00  2633.080078      -0.569444   0.000000  -5.223372
# 2018-12-10 00:00:00  2637.719971       0.000000   3.341171  -6.294928
# 2018-12-11 00:00:00  2636.780029      -0.551899   3.316993  -6.860947
# 2018-12-12 00:00:00  2651.070068       0.000000  13.558453  -6.458400
# 2018-12-13 00:00:00  2650.540039       0.000000  13.501326  -6.109846
# 2018-12-14 00:00:00  2599.949951      -0.907713   9.421121  -8.285473
# 2018-12-17 00:00:00  2545.939941      -0.950848   6.991787 -12.490281
#
#                         macds     macdh
# date
# 2018-12-03 00:00:00  0.000000  0.000000
# 2018-12-04 00:00:00 -1.125660 -0.900528
# 2018-12-06 00:00:00 -1.774659 -0.934560
# 2018-12-07 00:00:00 -2.942922 -2.280449
# 2018-12-10 00:00:00 -3.940068 -2.354860
# 2018-12-11 00:00:00 -4.731789 -2.129158
# 2018-12-12 00:00:00 -5.168748 -1.289652
# 2018-12-13 00:00:00 -5.394912 -0.714934
# 2018-12-14 00:00:00 -6.062646 -2.222828
# 2018-12-17 00:00:00 -7.502809 -4.987472

# %% [markdown]
# ## Experiments: Train and Test

# %%
import pandas as pd
import os
from sklearn.model_selection import TimeSeriesSplit

# Set the number of splits (folds)
n_splits = 10

# Initialize TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=n_splits)

# Create a list to store the folds
folds = []
i = 0
for train_index, test_index in tscv.split(df_filtered):
    # Extract DataFrames for the current fold
    train_fold = df_filtered.iloc[train_index].copy()
    test_fold = df_filtered.iloc[test_index].copy()

    # Combine train and test DataFrames into a single DataFrame for the current fold
    combined_fold = pd.concat([train_fold, test_fold])

    #save the data
    if not os.path.exists("/content/fold"):
      os.makedirs("/content/fold")
    combined_fold.to_csv('fold/preprocessed_dataset_{}.csv'.format(i), index=True)

    i += 1

# %%
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch

# %%
args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'custom' # data
args.root_path = '/content/' # root path of data file
args.data_path = 'preprocessed_dataset.csv' # data file
args.features = 'M' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'close' # target feature in S or MS task
args.freq = 'd' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 10 # input sequence length of Informer encoder
args.label_len = 5 # start token length of Informer decoder
args.pred_len = 1 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 7 # encoder input size
args.dec_in = 7 # decoder input size
args.c_out = 7 # output size
args.factor = 5 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder
args.mix = True
args.padding = 0
args.freq = 'd'

args.batch_size = 24
args.learning_rate = 0.0001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr = 1
args.train_epochs = 100
args.patience = 3
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

# %%
args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
# !rm -r /content/results
# Out:
# rm: cannot remove '/content/results': No such file or directory

# %%
for _ in range (i):
  # Set augments by using data name and adjust the encoder decoder size (for MS), based on features
  data_parser = {
      'custom':{'data':'fold/preprocessed_dataset_{}.csv'.format(_),'T':'close','M':[6,6,6],'S':[1,1,1],'MS':[6,6,1]},
  }
  if args.data in data_parser.keys():
      data_info = data_parser[args.data]
      args.data_path = data_info['data']
      args.target = data_info['T']
      args.enc_in, args.dec_in, args.c_out = data_info[args.features]
      args.detail_freq = args.freq
  args.freq = args.freq[-1:]
  print('Args in experiment:')
  print(args)
  Exp = Exp_Informer
  for ii in range(args.itr):
      # setting record of experiments
      setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}_fold{}'.format(args.model, args.data, args.features,
                  args.seq_len, args.label_len, args.pred_len,
                  args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii, _)

      # set experiments
      exp = Exp(args)

      # train
      print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
      exp.train(setting,_)

      # test
      print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
      exp.test(setting)

      torch.cuda.empty_cache()
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/content/', 'data_path': 'fold/preprocessed_dataset_0.csv', 'features': 'M', 'target': 'close', 'freq': 'd', 'checkpoints': './informer_checkpoints', 'seq_len': 10, 'label_len': 5, 'pred_len': 1, 'enc_in': 6, 'dec_in': 6, 'c_out': 6, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 151
# val 24
# test 46
# Epoch: 1 cost time: 3.839615821838379
# Epoch: 1, Steps: 6 | Train Loss: 0.5894917 Vali Loss: 0.3952059 Test Loss: 0.4642361
# Validation loss decreased (inf --> 0.395206).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 2.8463518619537354
# Epoch: 2, Steps: 6 | Train Loss: 0.3385801 Vali Loss: 0.4196353 Test Loss: 0.4439259
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 2.531050682067871
# Epoch: 3, Steps: 6 | Train Loss: 0.2557933 Vali Loss: 0.2922953 Test Loss: 0.3552614
# Validation loss decreased (0.395206 --> 0.292295).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 2.538109064102173
# Epoch: 4, Steps: 6 | Train Loss: 0.2204481 Vali Loss: 0.2388118 Test Loss: 0.3326792
# Validation loss decreased (0.292295 --> 0.238812).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.320935010910034
# Epoch: 5, Steps: 6 | Train Loss: 0.2068072 Vali Loss: 0.2410578 Test Loss: 0.3295858
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 2.5349910259246826
# Epoch: 6, Steps: 6 | Train Loss: 0.1960485 Vali Loss: 0.2421428 Test Loss: 0.3288344
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 2.5518898963928223
# Epoch: 7, Steps: 6 | Train Loss: 0.2086326 Vali Loss: 0.2430566 Test Loss: 0.3323984
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 46
# test shape: (1, 24, 1, 6) (1, 24, 1, 6)
# test shape: (24, 1, 6) (24, 1, 6)
# mse:0.33117935061454773, mae:0.3202054798603058
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/content/', 'data_path': 'fold/preprocessed_dataset_1.csv', 'features': 'M', 'target': 'close', 'freq': 'd', 'checkpoints': './informer_checkpoints', 'seq_len': 10, 'label_len': 5, 'pred_len': 1, 'enc_in': 6, 'dec_in': 6, 'c_out': 6, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 232
# val 35
# test 69
# Epoch: 1 cost time: 4.283029317855835
# Epoch: 1, Steps: 9 | Train Loss: 0.5387917 Vali Loss: 0.5206245 Test Loss: 4.6012673
# Validation loss decreased (inf --> 0.520625).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.6954808235168457
# Epoch: 2, Steps: 9 | Train Loss: 0.3050747 Vali Loss: 0.3694690 Test Loss: 4.7797856
# Validation loss decreased (0.520625 --> 0.369469).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3.6296050548553467
# Epoch: 3, Steps: 9 | Train Loss: 0.2521276 Vali Loss: 0.3799766 Test Loss: 4.4362359
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.444855451583862
# Epoch: 4, Steps: 9 | Train Loss: 0.2311536 Vali Loss: 0.2900482 Test Loss: 4.3536334
# Validation loss decreased (0.369469 --> 0.290048).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.6887450218200684
# Epoch: 5, Steps: 9 | Train Loss: 0.2174978 Vali Loss: 0.3324584 Test Loss: 4.3875656
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 3.539074659347534
# Epoch: 6, Steps: 9 | Train Loss: 0.2116190 Vali Loss: 0.3200766 Test Loss: 4.4017086
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.380266427993774
# Epoch: 7, Steps: 9 | Train Loss: 0.2087380 Vali Loss: 0.3565788 Test Loss: 4.4106245
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 69
# test shape: (2, 24, 1, 6) (2, 24, 1, 6)
# test shape: (48, 1, 6) (48, 1, 6)
# mse:4.395462989807129, mae:1.349791407585144
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/content/', 'data_path': 'fold/preprocessed_dataset_2.csv', 'features': 'M', 'target': 'close', 'freq': 'd', 'checkpoints': './informer_checkpoints', 'seq_len': 10, 'label_len': 5, 'pred_len': 1, 'enc_in': 6, 'dec_in': 6, 'c_out': 6, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold2>>>>>>>>>>>>>>>>>>>>>>>>>>
# train
 'pred_len': 1, 'enc_in': 6, 'dec_in': 6, 'c_out': 6, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 24, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'd'}
# Use CPU
# >>>>>>>start training : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold9>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 876
# val 127
# test 253
# Epoch: 1 cost time: 15.383849620819092
# Epoch: 1, Steps: 36 | Train Loss: 0.4078228 Vali Loss: 0.3073615 Test Loss: 0.2773827
# Validation loss decreased (inf --> 0.307362).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 16.216728687286377
# Epoch: 2, Steps: 36 | Train Loss: 0.2520749 Vali Loss: 0.3603151 Test Loss: 0.2607666
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 15.305142879486084
# Epoch: 3, Steps: 36 | Train Loss: 0.2222682 Vali Loss: 0.3181055 Test Loss: 0.2685755
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 15.437936067581177
# Epoch: 4, Steps: 36 | Train Loss: 0.2140054 Vali Loss: 0.2880144 Test Loss: 0.2343268
# Validation loss decreased (0.307362 --> 0.288014).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 15.296735048294067
# Epoch: 5, Steps: 36 | Train Loss: 0.2057788 Vali Loss: 0.2769737 Test Loss: 0.2265424
# Validation loss decreased (0.288014 --> 0.276974).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 15.232031106948853
# Epoch: 6, Steps: 36 | Train Loss: 0.2034104 Vali Loss: 0.2792436 Test Loss: 0.2247831
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 15.79407024383545
# Epoch: 7, Steps: 36 | Train Loss: 0.2038605 Vali Loss: 0.2795401 Test Loss: 0.2240237
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 15.146525859832764
# Epoch: 8, Steps: 36 | Train Loss: 0.2016748 Vali Loss: 0.2763134 Test Loss: 0.2241463
# Validation loss decreased (0.276974 --> 0.276313).  Saving model ...
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 15.312629222869873
# Epoch: 9, Steps: 36 | Train Loss: 0.2024166 Vali Loss: 0.2832258 Test Loss: 0.2238917
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-07
# Epoch: 10 cost time: 15.4110586643219
# Epoch: 10, Steps: 36 | Train Loss: 0.2010239 Vali Loss: 0.2714539 Test Loss: 0.2238760
# Validation loss decreased (0.276313 --> 0.271454).  Saving model ...
# Updating learning rate to 1.953125e-07
# Epoch: 11 cost time: 15.318169116973877
# Epoch: 11, Steps: 36 | Train Loss: 0.2004717 Vali Loss: 0.2860741 Test Loss: 0.2240533
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 9.765625e-08
# Epoch: 12 cost time: 15.885651588439941
# Epoch: 12, Steps: 36 | Train Loss: 0.2018886 Vali Loss: 0.2777472 Test Loss: 0.2234994
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 4.8828125e-08
# Epoch: 13 cost time: 16.646739721298218
# Epoch: 13, Steps: 36 | Train Loss: 0.2006420 Vali Loss: 0.2786810 Test Loss: 0.2240316
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftM_sl10_ll5_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0_fold9<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 253
# test shape: (10, 24, 1, 6) (10, 24, 1, 6)
# test shape: (240, 1, 6) (240, 1, 6)
# mse:0.23036660254001617, mae:0.2853272259235382

# %% [markdown]
# ## Prediction

# %%
# If you already have a trained model, you can set the arguments and model path, then initialize a Experiment and use it to predict
# Prediction is a sequence which is adjacent to the last date of the data, and does not exist in the data
# If you want to get more information about prediction, you can refer to code `exp/exp_informer.py function predict()` and `data/data_loader.py class Dataset_Pred`

exp = Exp(args)

exp.predict(setting, True)
# Out:
# Use CPU
# pred 1

# %%
# the prediction will be saved in ./results/{setting}/real_prediction.npy
import numpy as np

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape
# Out:
# (1, 1, 6)

# %% [markdown]
# ## LSTM model as comparison

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from utils.metrics import metric

# Define sequence length
seq_len = 10

def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i])  # Contains feature
        y.append(data[i, 0])  # Close price is the target variable
    return np.array(X), np.array(y)


for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        traindata = np.load(folder_path+'/traindata.npy')
        flipped_array = np.flip(traindata[:,0], axis=1)
        X_train, y_train = create_sequences(flipped_array, seq_len)
        # Building the LSTM Model
        model = Sequential()
        model.add(LSTM(units=70, activation="tanh", return_sequences=True, input_shape=(seq_len, X_train.shape[2])))
        model.add(Dropout(0.2))
        model.add(LSTM(units=30, activation="tanh", return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=10, activation="tanh"))
        model.add(Dropout(0.2))
        model.add(Dense(units=1, activation="linear"))

        model.compile(optimizer='adam', loss='mean_squared_error')

        # Define early stopping
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Train the model with early stopping
        history = model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.1, callbacks=[early_stopping])

        # testing
        testdata = np.load(folder_path+'/true.npy')
        test_flipped_array = np.flip(testdata[:,0], axis=1)
        #test_flipped_array = np.flip(test_flipped_array, axis=1)
        X_test_new, y_test_new = create_sequences(test_flipped_array, seq_len)
        # Make predictions on the test set and inverse scale for true value comparison
        predictions = model.predict(X_test_new)

        # # Inverse transform the scaled values to original scale
        # predictions = scaler.inverse_transform(predictions.reshape(-1, 1))

        # # Inverse transform the y_test values to original scale for comparison
        # y_test_new = scaler.inverse_transform(y_test_new.reshape(-1, 1))


        # Calculate evaluation Metrics
        mae, mse, rmse, mape, mspe = metric(y_test_new, predictions)
        print(f'MSE: {mse}')
        print(f'MAE: {mae}')
        print(f'MAPE: {mape * 100:.2f}%')
        np.save(folder_path+'/metrics_lstm.npy', np.array([mae, mse, rmse, mape, mspe]))
        np.save(folder_path+'/pred_lstm.npy', predictions)

    else:
        print(f'Folder {folder_path} does not exist.')
# Out:
# Epoch 1/100
# 6/6 [==============================] - 7s 278ms/step - loss: 0.3677 - val_loss: 1.1752
# Epoch 2/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2260 - val_loss: 0.6962
# Epoch 3/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1635 - val_loss: 0.3422
# Epoch 4/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1113 - val_loss: 0.2032
# Epoch 5/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0886 - val_loss: 0.1391
# Epoch 6/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0849 - val_loss: 0.1470
# Epoch 7/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0743 - val_loss: 0.1705
# Epoch 8/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0632 - val_loss: 0.1882
# Epoch 9/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0677 - val_loss: 0.1848
# Epoch 10/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0828 - val_loss: 0.1653
# Epoch 11/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0649 - val_loss: 0.1532
# Epoch 12/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0651 - val_loss: 0.1388
# Epoch 13/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0650 - val_loss: 0.1374
# Epoch 14/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0640 - val_loss: 0.1258
# Epoch 15/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0586 - val_loss: 0.1250
# Epoch 16/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0678 - val_loss: 0.1429
# Epoch 17/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0537 - val_loss: 0.1311
# Epoch 18/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0560 - val_loss: 0.1195
# Epoch 19/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0583 - val_loss: 0.1357
# Epoch 20/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0398 - val_loss: 0.1272
# Epoch 21/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0516 - val_loss: 0.1109
# Epoch 22/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0486 - val_loss: 0.1119
# Epoch 23/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0596 - val_loss: 0.1114
# Epoch 24/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0466 - val_loss: 0.1052
# Epoch 25/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0477 - val_loss: 0.1256
# Epoch 26/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0452 - val_loss: 0.1240
# Epoch 27/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0525 - val_loss: 0.1253
# Epoch 28/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0415 - val_loss: 0.0939
# Epoch 29/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0398 - val_loss: 0.0870
# Epoch 30/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0606 - val_loss: 0.0960
# Epoch 31/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0366 - val_loss: 0.0821
# Epoch 32/100
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0445 - val_loss: 0.0745
# Epoch 33/100
# 6/6 [==============================] - 1s 114ms/step - loss: 0.0388 - val_loss: 0.0674
# Epoch 34/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0444 - val_loss: 0.0683
# Epoch 35/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0374 - val_loss: 0.0627
# Epoch 36/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0314 - val_loss: 0.0514
# Epoch 37/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0416 - val_loss: 0.0607
# Epoch 38/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0485 - val_loss: 0.0625
# Epoch 39/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0383 - val_loss: 0.0559
# Epoch 40/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0341 - val_loss: 0.0659
# Epoch 41/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0429 - val_loss: 0.0608
# Epoch 42/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0365 - val_loss: 0.0500
# Epoch 43/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0319 - val_loss: 0.0525
# Epoch 44/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0406 - val_loss: 0.0541
# Epoch 45/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0309 - val_loss: 0.0609
# Epoch 46/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0387 - val_loss: 0.0654
# Epoch 47/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0339 - val_loss: 0.0526
# Epoch 48/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0432 - val_loss: 0.0517
# Epoch 49/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0312 - val_loss: 0.0525
# Epoch 50/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0272 - val_loss: 0.0604
# Epoch 51/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0280 - val_loss: 0.0650
# Epoch 52/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0266 - val_loss: 0.0632
# 1/1 [==============================] - 2s 2s/step
# MSE: 0.05659925565123558
# MAE: 0.1888924390077591
# MAPE: 16.19%
# Epoch 1/100
# 10/10 [==============================] - 8s 299ms/step - loss: 0.4805 - val_loss: 0.3758
# Epoch 2/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2029 - val_loss: 0.1564
# Epoch 3/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0995 - val_loss: 0.0935
# Epoch 4/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0854 - val_loss: 0.1086
# Epoch 5/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0878 - val_loss: 0.1270
# Epoch 6/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0675 - val_loss: 0.1452
# Epoch 7/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0735 - val_loss: 0.1480
# Epoch 8/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0787 - val_loss: 0.1287
# Epoch 9/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0877 - val_loss: 0.1320
# Epoch 10/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0751 - val_loss: 0.1307
# Epoch 11/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0748 - val_loss: 0.1453
# Epoch 12/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0721 - val_loss: 0.1374
# Epoch 13/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0686 - val_loss: 0.1172
# 2/2 [==============================] - 1s 9ms/step
# MSE: 4.647056579589844
# MAE: 1.8814831972122192
# MAPE: 229.09%
# Epoch 1/100
# 14/14 [==============================] - 8s 115ms/step - loss: 0.3763 - val_loss: 0.8156
# Epoch 2/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1226 - val_loss: 0.6946
# Epoch 3/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1057 - val_loss: 0.8271
# Epoch 4/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0841 - val_loss: 0.8691
# Epoch 5/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0857 - val_loss: 0.9920
# Epoch 6/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0532 - val_loss: 0.9482
# Epoch 7/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0514 - val_loss: 0.9461
# Epoch 8/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0492 - val_loss: 0.9098
# Epoch 9/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0445 - val_loss: 0.9666
# Epoch 10/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0438 - val_loss: 0.8581
# Epoch 11/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0465 - val_loss: 0.9717
# Epoch 12/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0514 - val_loss: 0.9042
# 2/2 [==============================] - 1s 10ms/step
# MSE: 1.0208547115325928
# MAE: 0.797735869884491
# MAPE: 369.59%
# Epoch 1/100
# 17/17 [==============================] - 7s 121ms/step - loss: 0.5269 - val_loss: 0.0983
# Epoch 2/100
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2078 - val_loss: 0.2275
# Epoch 3/100
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1481 - val_loss: 0.2530
# Epoch 4/100
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1342 - val_loss: 0.1886
# Epoch 5/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.1158 - val_loss: 0.2050
# Epoch 6/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0952 - val_loss: 0.3032
# Epoch 7/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.1159 - val_loss: 0.1776
# Epoch 8/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0956 - val_loss: 0.2263
# Epoch 9/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0940 - val_loss: 0.2031
# Epoch 10/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0993 - val_loss: 0.1693
# Epoch 11/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0931 - val_loss: 0.2068
# 3/3 [==============================] - 2s 8ms/step
# MSE: 5.490598678588867
# MAE: 2.2108476161956787
# MAPE: 180.10%
# Epoch 1/100
# 21/21 [==============================] - 8s 102ms/step - loss: 0.4272 - val_loss: 0.7725
# Epoch 2/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1428 - val_loss: 0.2968
# Epoch 3/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1103 - val_loss: 0.2629
# Epoch 4/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1079 - val_loss: 0.2762
# Epoch 5/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0976 - val_loss: 0.2106
# Epoch 6/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0794 - val_loss: 0.1971
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0846 - val_loss: 0.2614
# Epoch 8/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0850 - val_loss: 0.1748
# Epoch 9/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0645 - val_loss: 0.2944
# Epoch 10/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0807 - val_loss: 0.1930
# Epoch 11/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0749 - val_loss: 0.1625
# Epoch 12/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0738 - val_loss: 0.2000
# Epoch 13/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0721 - val_loss: 0.2009
# Epoch 14/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0725 - val_loss: 0.1285
# Epoch 15/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0572 - val_loss: 0.2050
# Epoch 16/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0624 - val_loss: 0.1253
# Epoch 17/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0609 - val_loss: 0.1936
# Epoch 18/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0645 - val_loss: 0.1645
# Epoch 19/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0556 - val_loss: 0.1986
# Epoch 20/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0502 - val_loss: 0.1248
# Epoch 21/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0657 - val_loss: 0.1675
# Epoch 22/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0610 - val_loss: 0.2304
# Epoch 23/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0602 - val_loss: 0.1282
# Epoch 24/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0632 - val_loss: 0.1565
# Epoch 25/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0686 - val_loss: 0.1052
# Epoch 26/100
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0633 - val_loss: 0.3074
# Epoch 27/100
# 21/21 [==============================] - 1s 27ms/step - loss: 0.0591 - val_loss: 0.2321
# Epoch 28/100
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0566 - val_loss: 0.1557
# Epoch 29/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0497 - val_loss: 0.1624
# Epoch 30/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0543 - val_loss: 0.1228
# Epoch 31/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0567 - val_loss: 0.1724
# Epoch 32/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0572 - val_loss: 0.1293
# Epoch 33/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0523 - val_loss: 0.1119
# Epoch 34/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0492 - val_loss: 0.1759
# Epoch 35/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0488 - val_loss: 0.1183
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x794ec0dee950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 1s 7ms/step
# MSE: 7.181757926940918
# MAE: 2.60621976852417
# MAPE: 135.42%
# Epoch 1/100
# 25/25 [==============================] - 8s 68ms/step - loss: 0.2825 - val_loss: 1.0040
# Epoch 2/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1012 - val_loss: 0.7086
# Epoch 3/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0659 - val_loss: 0.5503
# Epoch 4/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0665 - val_loss: 0.4722
# Epoch 5/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0560 - val_loss: 0.5692
# Epoch 6/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0544 - val_loss: 0.4032
# Epoch 7/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0511 - val_loss: 0.5271
# Epoch 8/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0581 - val_loss: 0.3467
# Epoch 9/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0543 - val_loss: 0.3233
# Epoch 10/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0510 - val_loss: 0.3394
# Epoch 11/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0483 - val_loss: 0.3656
# Epoch 12/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0560 - val_loss: 0.1902
# Epoch 13/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0419 - val_loss: 0.2696
# Epoch 14/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0488 - val_loss: 0.3583
# Epoch 15/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0462 - val_loss: 0.2775
# Epoch 16/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0492 - val_loss: 0.2458
# Epoch 17/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0434 - val_loss: 0.2582
# Epoch 18/100
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0442 - val_loss: 0.2304
# Epoch 19/100
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0496 - val_loss: 0.0858
# Epoch 20/100
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0423 - val_loss: 0.2274
# Epoch 21/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0467 - val_loss: 0.1536
# Epoch 22/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0428 - val_loss: 0.2717
# Epoch 23/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0403 - val_loss: 0.1142
# Epoch 24/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0397 - val_loss: 0.1791
# Epoch 25/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0437 - val_loss: 0.0802
# Epoch 26/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0402 - val_loss: 0.1240
# Epoch 27/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0422 - val_loss: 0.0665
# Epoch 28/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0417 - val_loss: 0.0457
# Epoch 29/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0448 - val_loss: 0.0328
# Epoch 30/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0353 - val_loss: 0.0696
# Epoch 31/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0330 - val_loss: 0.0479
# Epoch 32/100
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0363 - val_loss: 0.0325
# Epoch 33/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0337 - val_loss: 0.0556
# Epoch 34/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0394 - val_loss: 0.0641
# Epoch 35/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0375 - val_loss: 0.1519
# Epoch 36/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0404 - val_loss: 0.2689
# Epoch 37/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0352 - val_loss: 0.1031
# Epoch 38/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0397 - val_loss: 0.0595
# Epoch 39/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0374 - val_loss: 0.0416
# Epoch 40/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0337 - val_loss: 0.0490
# Epoch 41/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0336 - val_loss: 0.1499
# Epoch 42/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0362 - val_loss: 0.0728
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x794ea9d24d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 [==============================] - 2s 8ms/step
# MSE: 2.437828302383423
# MAE: 1.5095701217651367
# MAPE: 60.43%
# Epoch 1/100
# 28/28 [==============================] - 8s 62ms/step - loss: 0.2830 - val_loss: 0.6933
# Epoch 2/100
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0730 - val_loss: 0.3662
# Epoch 3/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0528 - val_loss: 0.4090
# Epoch 4/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0488 - val_loss: 0.3387
# Epoch 5/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0463 - val_loss: 0.2365
# Epoch 6/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0462 - val_loss: 0.2550
# Epoch 7/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0432 - val_loss: 0.2074
# Epoch 8/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0424 - val_loss: 0.1840
# Epoch 9/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0363 - val_loss: 0.2211
# Epoch 10/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0420 - val_loss: 0.1328
# Epoch 11/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0401 - val_loss: 0.1635
# Epoch 12/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0373 - val_loss: 0.0919
# Epoch 13/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0395 - val_loss: 0.1849
# Epoch 14/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0350 - val_loss: 0.0969
# Epoch 15/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0397 - val_loss: 0.1656
# Epoch 16/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0325 - val_loss: 0.1566
# Epoch 17/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0346 - val_loss: 0.1446
# Epoch 18/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0334 - val_loss: 0.2333
# Epoch 19/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0343 - val_loss: 0.1102
# Epoch 20/100
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0342 - val_loss: 0.1269
# Epoch 21/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0316 - val_loss: 0.1351
# Epoch 22/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0305 - val_loss: 0.1473
# 5/5 [==============================] - 1s 7ms/step
# MSE: 0.9597252607345581
# MAE: 0.8408385515213013
# MAPE: 54.46%
# Epoch 1/100
# 31/31 [==============================] - 8s 57ms/step - loss: 0.2060 - val_loss: 0.1080
# Epoch 2/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0559 - val_loss: 0.2116
# Epoch 3/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0427 - val_loss: 0.1177
# Epoch 4/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0368 - val_loss: 0.1048
# Epoch 5/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0319 - val_loss: 0.1060
# Epoch 6/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0370 - val_loss: 0.1425
# Epoch 7/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0354 - val_loss: 0.0825
# Epoch 8/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0345 - val_loss: 0.0674
# Epoch 9/100
# 31/31 [==============================] - 1s 39ms/step - loss: 0.0322 - val_loss: 0.0204
# Epoch 10/100
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0307 - val_loss: 0.0838
# Epoch 11/100
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0326 - val_loss: 0.1168
# Epoch 12/100
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0311 - val_loss: 0.0430
# Epoch 13/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0284 - val_loss: 0.0527
# Epoch 14/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0287 - val_loss: 0.0376
# Epoch 15/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0331 - val_loss: 0.1374
# Epoch 16/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0318 - val_loss: 0.0237
# Epoch 17/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0286 - val_loss: 0.0194
# Epoch 18/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0335 - val_loss: 0.0378
# Epoch 19/100
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0296 - val_loss: 0.0929
# Epoch 20/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0281 - val_loss: 0.1102
# Epoch 21/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0298 - val_loss: 0.0767
# Epoch 22/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0283 - val_loss: 0.0349
# Epoch 23/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0273 - val_loss: 0.0129
# Epoch 24/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0259 - val_loss: 0.0738
# Epoch 25/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0264 - val_loss: 0.1169
# Epoch 26/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0277 - val_loss: 0.0684
# Epoch 27/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0288 - val_loss: 0.0610
# Epoch 28/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0258 - val_loss: 0.1040
# Epoch 29/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0278 - val_loss: 0.0207
# Epoch 30/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0280 - val_loss: 0.0208
# Epoch 31/100
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0286 - val_loss: 0.0516
# Epoch 32/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0292 - val_loss: 0.0781
# Epoch 33/100
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0252 - val_loss: 0.0367
# 6/6 [==============================] - 1s 6ms/step
# MSE: 0.2861616015434265
# MAE: 0.43164628744125366
# MAPE: 52.17%
# Epoch 1/100
# 36/36 [==============================] - 7s 52ms/step - loss: 0.2539 - val_loss: 0.1704
# Epoch 2/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0465 - val_loss: 0.1628
# Epoch 3/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.0384 - val_loss: 0.1420
# Epoch 4/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.0375 - val_loss: 0.1294
# Epoch 5/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.0389 - val_loss: 0.1237
# Epoch 6/100
# 36/36 [==============================] - 1s 21ms/step - loss: 0.0304 - val_loss: 0.0623
# Epoch 7/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0347 - val_loss: 0.0971
# Epoch 8/100
# 36/36 [==============================] - 1s 18ms/step - loss: 0.0363 - val_loss: 0.0972
# Epoch 9/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0316 - val_loss: 0.0735
# Epoch 10/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0329 - val_loss: 0.0905
# Epoch 11/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0336 - val_loss: 0.0801
# Epoch 12/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0321 - val_loss: 0.0789
# Epoch 13/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0280 - val_loss: 0.0348
# Epoch 14/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0321 - val_loss: 0.0690
# Epoch 15/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0286 - val_loss: 0.0730
# Epoch 16/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0320 - val_loss: 0.0481
# Epoch 17/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0315 - val_loss: 0.0687
# Epoch 18/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0275 - val_loss: 0.0661
# Epoch 19/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0298 - val_loss: 0.0404
# Epoch 20/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0293 - val_loss: 0.0255
# Epoch 21/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0315 - val_loss: 0.0590
# Epoch 22/100
# 36/36 [==============================] - 1s 20ms/step - loss: 0.0283 - val_loss: 0.0593
# Epoch 23/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.0287 - val_loss: 0.0721
# Epoch 24/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0294 - val_loss: 0.0714
# Epoch 25/100
# 36/36 [==============================] - 1s 22ms/step - loss: 0.0289 - val_loss: 0.0972
# Epoch 26/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0251 - val_loss: 0.0895
# Epoch 27/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0282 - val_loss: 0.0662
# Epoch 28/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0298 - val_loss: 0.0557
# Epoch 29/100
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0312 - val_loss: 0.0333
# Epoch 30/100
# 36/36 [==============================] - 1s 18ms/step - loss: 0.0256 - val_loss: 0.0824
# 7/7 [==============================] - 1s 6ms/step
# MSE: 0.18445250391960144
# MAE: 0.34450864791870117
# MAPE: 249.84%
# Epoch 1/100
# 39/39 [==============================] - 8s 49ms/step - loss: 0.3363 - val_loss: 0.0885
# Epoch 2/100
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0626 - val_loss: 0.0880
# Epoch 3/100
# 39/39 [==============================] - 1s 27ms/step - loss: 0.0502 - val_loss: 0.0524
# Epoch 4/100
# 39/39 [==============================] - 1s 28ms/step - loss: 0.0422 - val_loss: 0.0782
# Epoch 5/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0417 - val_loss: 0.0445
# Epoch 6/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0390 - val_loss: 0.0569
# Epoch 7/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0393 - val_loss: 0.0506
# Epoch 8/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0367 - val_loss: 0.0546
# Epoch 9/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0406 - val_loss: 0.0351
# Epoch 10/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0385 - val_loss: 0.0464
# Epoch 11/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0384 - val_loss: 0.0512
# Epoch 12/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0374 - val_loss: 0.0378
# Epoch 13/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0322 - val_loss: 0.0498
# Epoch 14/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0379 - val_loss: 0.0423
# Epoch 15/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0344 - val_loss: 0.0464
# Epoch 16/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0318 - val_loss: 0.0379
# Epoch 17/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.0330 - val_loss: 0.0468
# Epoch 18/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.0342 - val_loss: 0.0438
# Epoch 19/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0346 - val_loss: 0.0417
# 8/8 [==============================] - 2s 5ms/step
# MSE: 0.16236108541488647
# MAE: 0.3288123607635498
# MAPE: 36.60%

# %%
for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        g_truth = np.load(folder_path+'/true.npy')
        pred_informer = np.load(folder_path+'/pred.npy')
        pred_lstm = np.load(folder_path+'/pred_lstm.npy')

        # Shift pred_lstm 10 steps forward
        x_values = np.arange(len(pred_lstm)) + 10

        plt.figure(figsize=(15, 6))
        plt.plot(g_truth[:,:,5], label='Actual Closing Prices')
        plt.plot(pred_informer[:,:,5], label='Informer')
        plt.plot(x_values, pred_lstm[:, 0], label='LSTM')
        plt.title('Stock Price Prediction')
        plt.xlabel('Index')
        plt.ylabel('Stock Price')
        plt.legend()
        plt.show()

# %%
mae = []
mse = []
rmse = []
mape = []
mspe = []

mael = []
msel = []
rmsel = []
mapel = []
mspel = []

for i in range(10):
    folder_path = os.path.join('./results/'+setting[:-1]+"{}".format(i))
    # Check if the folder exists
    if os.path.exists(folder_path):
        inf_m = np.load(folder_path+'/metrics.npy')
        l_m = np.load(folder_path+'/metrics_lstm.npy')
        mse.append(inf_m[1])
        rmse.append(inf_m[2])
        mape.append(inf_m[3])
        mspel.append(inf_m[4])
        mae.append(inf_m[0])

        msel.append(l_m[1])
        rmsel.append(l_m[2])
        mapel.append(l_m[3])
        mspel.append(l_m[4])
        mael.append(l_m[0])

# Calculate the standard deviation of MSE across folds
std_mse_inf = np.std(mse)
mean_mse_inf = np.mean(mse)
print("mean MSE Informer:", mean_mse_inf)
print("std MSE Informer: ", std_mse_inf)

# Calculate the standard deviation of MSE across folds
std_mse_lstm = np.std(msel)
mean_mse_lstm = np.mean(msel)
print("mean MSE LSTM:", mean_mse_lstm)
print("std MSE LSTM: ", std_mse_lstm)
# Out:
# mean MSE Informer: 0.88083714
# std MSE Informer:  1.1908661
# mean MSE LSTM: 2.2427394
# std MSE LSTM:  2.4712818

# %%
# Calculate the standard deviation of MAE across folds
std_mae_inf = np.std(mae)
mean_mae_inf = np.mean(mae)
print("mean MAE Informer:", mean_mae_inf)
print("std MAE Informer: ", std_mae_inf)

# Calculate the standard deviation of MAE across folds
std_mae_lstm = np.std(mael)
mean_mae_lstm = np.mean(mael)
print("mean MAE LSTM:", mean_mae_lstm)
print("std MAE LSTM: ", std_mae_lstm)
# Out:
# mean MAE Informer: 0.54757065
# std MAE Informer:  0.28692645
# mean MAE LSTM: 1.1140555
# std MAE LSTM:  0.8294581

# %%
# Calculate the standard deviation of MAPE across folds
std_mape_inf = np.std(mape)
mean_mape_inf = np.mean(mape)
print("mean MAPE Informer:", mean_mape_inf)
print("std MAPE Informer: ", std_mape_inf)

# Calculate the standard deviation of MAPE across folds
std_mape_lstm = np.std(mapel)
mean_mape_lstm = np.mean(mapel)
print("mean MAPE LSTM:", mean_mape_lstm)
print("std MAPE LSTM: ", std_mape_lstm)
# Out:
# mean MAPE Informer: 1.3341968
# std MAPE Informer:  0.67458355
# mean MAPE LSTM: 1.3838842
# std MAPE LSTM:  1.1031629

# %%
# Calculate the standard deviation of RMSE across folds
std_rmse_inf = np.std(rmse)
mean_rmse_inf = np.mean(rmse)
print("mean RMSE Informer:", mean_rmse_inf)
print("std RMSE Informer: ", std_rmse_inf)

# Calculate the standard deviation of RMSE across folds
std_rmse_lstm = np.std(rmsel)
mean_rmse_lstm = np.mean(rmsel)
print("mean RMSE LSTM:", mean_rmse_lstm)
print("std RMSE LSTM: ", std_rmse_lstm)
# Out:
# mean RMSE Informer: 0.82542497
# std RMSE Informer:  0.44666642
# mean RMSE LSTM: 1.2335438
# std RMSE LSTM:  0.8491817

# %% [markdown]
# ###Informer

# %%
# When we finished exp.train(setting) and exp.test(setting), we will get a trained model and the results of test experiment
# The results of test experiment will be saved in ./results/{setting}/pred.npy (prediction of test dataset) and ./results/{setting}/true.npy (groundtruth of test dataset)
import numpy as np
preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

# [samples, pred_len, dimensions]
preds.shape, trues.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
# draw prediction
for i in range(5):
  # Make predictions on the test set and inverse scale for true value comparison
  # # Inverse transform the scaled values to original scale
  # preds[:,i,1] = scaler.inverse_transform(preds[:,i,1].reshape(-1, 1))
  # # Inverse transform the y_test values to original scale for comparison
  # trues[:,i,1] = scaler.inverse_transform(trues[:,i,1].reshape(-1, 1))
  plt.figure(figsize=(15, 6))
  plt.plot(trues[:,i,1], label='GroundTruth')
  plt.plot(preds[:,i,1], label='Prediction')
  plt.title('Stock Price Prediction')
  plt.xlabel('Index')
  plt.ylabel('Stock Price')
  plt.legend()
  plt.show()

  # Calculate MAE and MAPE
  mae_inf = mean_absolute_error(trues[:,i,1], preds[:,i,1])
  mape_inf = mean_absolute_percentage_error(trues[:,i,1], preds[:,i,1])

  print(f'MAE of Informer: {mae_inf}')
  print(f'MAPE of Informer: {mape_inf * 100:.2f}%')

# %% [markdown]
# ###LSTM

# %%
# Merge data on the date column
merged_data = pd.read_csv('preprocessed_dataset.csv')

# Selecting the relevant columns only after merging to preserve DataFrame structure.
# columns_to_keep = ["Close"] # Only History
columns_to_keep = ["Close", "FinBERT score"] # with Sentiment
# columns_to_keep = ["close",	"rsi",	"macd",	"macds",	"macdh"]# with TA
# columns_to_keep = ["close",	"finbert score",	"rsi",	"macd",	"macds",	"macdh"]# with Sentiment&TA

merged_data = merged_data[columns_to_keep]

# Function to create sequences with sentiment score embedded
def create_sequences(data, seq_len):
    X, y = [], []
    data_values = data.values
    for i in range(seq_len, len(data)):
        X.append(data_values[i-seq_len:i])  # Contains feature
        y.append(data_values[i, 0])  # Close price is the target variable
    return np.array(X), np.array(y)

# Define sequence length
seq_len = 10

# Create sequences and targets
X, y = create_sequences(merged_data, seq_len)

# Feature scaling only the "Close" column
scaler = StandardScaler()
y = y.reshape(-1, 1)  # Reshaping for the scaler
scaled_close = scaler.fit_transform(y)

#only History
# scaled_features = scaled_close

#with Sentiment
scaled_features = np.hstack([scaled_close, merged_data['FinBERT score'].values[seq_len-1:-1].reshape(-1, 1)])

#with TA
# selected_columns = merged_data[['rsi', 'macd', 'macds', 'macdh']].values

#with Sentiment & TA
# Extract the selected columns from merged_data
# selected_columns = merged_data[['finbert score', 'rsi', 'macd', 'macds', 'macdh']].values

# Ensure that selected_columns has the same length as scaled_close
# selected_columns = selected_columns[seq_len-1:seq_len-1+len(scaled_close)]
# scaled_features = np.hstack([scaled_close, selected_columns])

X_scaled, y_scaled = create_sequences(pd.DataFrame(scaled_features, columns=columns_to_keep), seq_len)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled.squeeze(), test_size=0.18, shuffle=False)

# Building the LSTM Model
model = Sequential()
model.add(LSTM(units=70, activation="tanh", return_sequences=True, input_shape=(seq_len, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=30, activation="tanh", return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=10, activation="tanh"))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation="linear"))

model.compile(optimizer='adam', loss='mean_squared_error')

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, epochs=100, batch_size=24, validation_split=0.1, callbacks=[early_stopping])

# Evaluate the model on the test set
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')

# Plot training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Inverse scaling the output for evaluation purposes
for i in range(5):
  flipped_array = np.flip(trues[:,i], axis=1)
  X_test_new, y_test_new = create_sequences(flipped_array, seq_len)
  # Make predictions on the test set and inverse scale for true value comparison
  predictions = model.predict(X_test_new)

  # # Inverse transform the scaled values to original scale
  # predictions = scaler.inverse_transform(predictions.reshape(-1, 1))

  # # Inverse transform the y_test values to original scale for comparison
  # y_test_new = scaler.inverse_transform(y_test_new.reshape(-1, 1))


  # Calculate evaluation Metrics
  mae, mse, rmse, mape, mspe = metric(y_test_new, predictions)

  print(f'MAE: {mae}')
  print(f'MAPE: {mape * 100:.2f}%')

  # Plot predictions vs actual prices
  plt.figure(figsize=(15, 6))
  plt.plot(y_test_new, label='Actual Prices')
  plt.plot(predictions, label='Predicted Prices')
  plt.title('Stock Price Prediction')
  plt.xlabel('Index')
  plt.ylabel('Stock Price')
  plt.legend()
  plt.show()
